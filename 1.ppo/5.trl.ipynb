# %%
import torch
import random
import os

os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
device = 'cuda' if torch.cuda.is_available() else 'cpu'
b = 128
len_question = 6
len_answer = 32

from transformers import AutoTokenizer

tokenizer_actor = AutoTokenizer.from_pretrained('lvwerra/gpt2-imdb')
tokenizer_actor.pad_token = tokenizer_actor.eos_token

tokenizer_critic = AutoTokenizer.from_pretrained('lvwerra/distilbert-imdb')

tokenizer_actor, tokenizer_critic
# Out:
# (GPT2TokenizerFast(name_or_path='lvwerra/gpt2-imdb', vocab_size=50257, model_max_length=1024, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>', 'pad_token': '<|endoftext|>'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
#  	50256: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
#  },
#  DistilBertTokenizerFast(name_or_path='lvwerra/distilbert-imdb', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
#  	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
#  })

# %%
from datasets import load_dataset, concatenate_datasets

dataset = load_dataset('imdb')
dataset = concatenate_datasets(list(dataset.values()))
dataset = dataset.remove_columns(['label'])

dataset, dataset[0]
# Out:
# (Dataset({
#      features: ['text'],
#      num_rows: 100000
#  }),
#  {'text': 'I rented I AM CURIOUS-YELLOW from my video store because of all the controversy that surrounded it when it was first released in 1967. I also heard that at first it was seized by U.S. customs if it ever tried to enter this country, therefore being a fan of films considered "controversial" I really had to see this for myself.<br /><br />The plot is centered around a young Swedish drama student named Lena who wants to learn everything she can about life. In particular she wants to focus her attentions to making some sort of documentary on what the average Swede thought about certain political issues such as the Vietnam War and race issues in the United States. In between asking politicians and ordinary denizens of Stockholm about their opinions on politics, she has sex with her drama teacher, classmates, and married men.<br /><br />What kills me about I AM CURIOUS-YELLOW is that 40 years ago, this was considered pornographic. Really, the sex and nudity scenes are few and far between, even then it\'s not shot like some cheaply made porno. While my countrymen mind find it shocking, in reality sex and nudity are a major staple in Swedish cinema. Even Ingmar Bergman, arguably their answer to good old boy John Ford, had sex scenes in his films.<br /><br />I do commend the filmmakers for the fact that any sex shown in the film is shown for artistic purposes rather than just to shock people and make money to be shown in pornographic theaters in America. I AM CURIOUS-YELLOW is a good film for anyone wanting to study the meat and potatoes (no pun intended) of Swedish cinema. But really, this film doesn\'t have much of a plot.'})

# %%
from trl import AutoModelForCausalLMWithValueHead
from transformers import AutoModelForSequenceClassification

model_ppo = AutoModelForCausalLMWithValueHead.from_pretrained(
    'model/actor').to(device)
model_ppo_ref = AutoModelForCausalLMWithValueHead.from_pretrained(
    'model/actor').to(device)

model_critic = AutoModelForSequenceClassification.from_pretrained(
    'model/critic').to(device)

for i in model_ppo_ref.parameters():
    i.requires_grad_(False)

for i in model_critic.parameters():
    i.requires_grad_(False)

# %%
@torch.no_grad()
def get_data():
    #====question====
    label = random.choices(range(2), k=b)
    question = random.choices(dataset, k=b)
    question = [str(l) + ' ' + p['text'] for l, p in zip(label, question)]

    question = tokenizer_actor(question,
                               padding=True,
                               truncation=True,
                               max_length=len_question,
                               return_tensors='pt').input_ids.to(device)

    #====answer====
    answer = model_ppo.generate(input_ids=question,
                                min_length=-1,
                                max_length=len_question + len_answer,
                                pad_token_id=tokenizer_actor.pad_token_id,
                                eos_token_id=tokenizer_actor.eos_token_id,
                                top_k=0.0,
                                top_p=1.0,
                                do_sample=True)

    answer = answer[:, question.shape[1]:]

    #====reward====
    qa = torch.cat((question, answer), 1)
    qa = tokenizer_actor.batch_decode(qa, skip_special_tokens=True)
    qa = [i[2:] for i in qa]
    qa = tokenizer_critic(qa,
                          padding=True,
                          truncation=True,
                          max_length=50,
                          return_tensors='pt').to(device)

    reward = model_critic(**qa).logits

    label = torch.LongTensor(label).reshape(-1, 1).to(device)
    reward = reward.gather(1, label).squeeze(1)

    #裁剪
    answer_cut = []
    for i in answer:
        if tokenizer_actor.eos_token_id in i:
            idx = i.tolist().index(tokenizer_actor.eos_token_id)
            i = i[:idx]
        answer_cut.append(i)
    answer = answer_cut

    question = [i for i in question]
    reward = [i for i in reward]

    return question, answer, reward


get_data()
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ([tensor([  15, 2329, 2497, 2744,  261, 4533], device='cuda:0'),
#   tensor([   16, 40967,    11,   356,   923,   287], device='cuda:0'),
#   tensor([   16,   770,  2646,   318,   523, 10416], device='cuda:0'),
#   tensor([  16,  523, 3763,  340,  318, 2407], device='cuda:0'),
#   tensor([   16, 16140,   963,    11,   513,    14], device='cuda:0'),
#   tensor([  16,  632,  338,  262, 6983, 1810], device='cuda:0'),
#   tensor([   15, 21429,   278,   477,   616, 25495], device='cuda:0'),
#   tensor([  15,  770,  318,  257, 7906,  572], device='cuda:0'),
#   tensor([  15,  502,  290,  257, 2284,  489], device='cuda:0'),
#   tensor([   16,  7945,   262, 38957,  3227,  3146], device='cuda:0'),
#   tensor([  15,  770,  318,  257, 8258, 3807], device='cuda:0'),
#   tensor([   16, 13723,   350,  3733,    11,   428], device='cuda:0'),
#   tensor([   16, 18578,   780,   428,   318,  9309], device='cuda:0'),
#   tensor([  16, 1002,  345,  765,  284, 7030], device='cuda:0'),
#   tensor([  16,  770,  318,  281, 8082, 2646], device='cuda:0'),
#   tensor([  16,  314, 1107, 1842,  262, 7348], device='cuda:0'),
#   tensor([   15, 11136,  7334,   510,   287,   262], device='cuda:0'),
#   tensor([  15,  314,  655,  550,  262, 3663], device='cuda:0'),
#   tensor([  15,  770, 3807,  373, 2035, 1165], device='cuda:0'),
#   tensor([  16,  314, 3505,  326, 1948, 4471], device='cuda:0'),
#   tensor([  15,  314,  373,  257, 4336,  286], device='cuda:0'),
#   tensor([  15,  314, 1101, 1464,  287,  329], device='cuda:0'),
#   tensor([   15,   383, 20617, 10530,   326,   749], device='cuda:0'),
#   tensor([   15,   383, 45255,   364,  1107,   318], device='cuda:0'),
#   tensor([  16,  770,  815,  307,  616, 1611], device='cuda:0'),
#   tensor([  15,  314, 2497,  428, 3807,  938], device='cuda:0'),
#   tensor([  15,  314, 1107, 8359,  428, 1111], device='cuda:0'),
#   tensor([  15,  428, 3807, 3173,  517,  621], device='cuda:0'),
#   tensor([  16, 4746,  370, 9346,  318,  530], device='cuda:0'),
#   tensor([   16,   317,   582,   318, 37234,   465], device='cuda:0'),
#   tensor([   16,  3274,   286,   477,    13, 10358], device='cuda:0'),
#   tensor([   16,   366,    47, 11020,   379, 18087], device='cuda:0'),
#   tensor([  16, 1400,   11,  314, 4398,  470], device='cuda:0'),
#   tensor([  16,  314, 1101,  407,  994,  284], device='cuda:0'),
#   tensor([  16, 1114,  883,  286,  345,  508], device='cuda:0'),
#   tensor([  16,  632,  373, 3621,  284,  766], device='cuda:0'),
#   tensor([  15,  770, 2646,  561,  423,  925], device='cuda:0'),
#   tensor([  15,  314,  655, 5201, 4964,  428], device='cuda:0'),
#   tensor([   16,   314,  2540, 10311, 14260,  6547], device='cuda:0'),
#   tensor([  15,  383, 7849,  318,  257,  845], device='cuda:0'),
#   tensor([   15,   383, 28763,   286,   367,    13], device='cuda:0'),
#   tensor([   16, 23486,   357, 22245,   440,     6], device='cuda:0'),
#   tensor([  16,  314, 2921, 6857, 6912,  257], device='cuda:0'),
#   tensor([  16,  314,  561, 2494,  428,  905], device='cuda:0'),
#   tensor([  16, 2293, 4379,  428, 2646,  314], device='cuda:0'),
#   tensor([  16,  314, 1276,  910,  326,  314], device='cuda:0'),
#   tensor([  15, 2011, 9987,  329,  257, 2081], device='cuda:0'),
#   tensor([   15, 36110,   366,    46,   824,  2521], device='cuda:0'),
#   tensor([   15,   317,  2407,  6678, 13913,    88], device='cuda:0'),
#   tensor([   15,   366,    39, 42661,   318,   618], device='cuda:0'),
#   tensor([  16, 1081,  281, 1605, 3942,  287], device='cuda:0'),
#   tensor([ 16, 314, 892, 262, 938, 317], device='cuda:0'),
#   tensor([  16, 1869,  428, 3807,  318,  257], device='cuda:0'),
#   tensor([   16,   632,  2753, 16336,   284,   651], device='cuda:0'),
#   tensor([  16, 1279, 1671, 1220, 6927, 1671], device='cuda:0'),
#   tensor([  16,  314, 1276,  910,  428, 3807], device='cuda:0'),
#   tensor([  16, 6911,  935, 5527,   11, 6454], device='cuda:0'),
#   tensor([   16, 36110,   262, 21104, 15032,  3601], device='cuda:0'),
#   tensor([   15, 19882, 17376,    88,  3862,  5027], device='cuda:0'),
#   tensor([   16,   775, 26399,   262,  3807,   290], device='cuda:0'),
#   tensor([  16,  314, 1107,  836,  470,  760], device='cuda:0'),
#   tensor([   15,   314,   760,   326,  5398, 22041], device='cuda:0'),
#   tensor([  16, 1649,  314,  717, 2497,  366], device='cuda:0'),
#   tensor([   16, 25498,  7369,   278,   318,   530], device='cuda:0'),
#   tensor([  15, 4930, 7777,   11,  530, 4675], device='cuda:0'),
#   tensor([   15, 11182,   554,   383,  6233,   357], device='cuda:0'),
#   tensor([   15, 19770, 42058,   287,   262,  5707], device='cuda:0'),
#   tensor([   16, 17973,  4950,    13,  1881,   286], device='cuda:0'),
#   tensor([   15,   389, 11330,   286,   428, 24168], device='cuda:0'),
#   tensor([  15, 3894,   11,  644,  460,  314], device='cuda:0'),
#   tensor([  15,  314,  655, 9569,  262, 2646], device='cuda:0'),
#   tensor([  15,  632,  338, 1682,  257,  922], device='cuda:0'),
#   tensor([   15,  2080,   262, 12267,  4485,   284], device='cuda:0'),
#   tensor([   16,   770, 18404, 10512,   468,   340], device='cuda:0'),
#   tensor([  15,  314,  423,  587, 1262, 8959], device='cuda:0'),
#   tensor([  16, 9993,  355,  314, 1244,   11], device='cuda:0'),
#   tensor([   16,   317,  2274,   302,    12, 21949], device='cuda:0'),
#   tensor([  16,  770,  318,  257,  275, 6457], device='cuda:0'),
#   tensor([   16, 29899,    11,   262,  1306,   640], device='cuda:0'),
#   tensor([   15,   770,  2646,   318,  1107, 18824], device='cuda:0'),
#   tensor([  15,  314, 2497,  428, 3807,  812], device='cuda:0'),
#   tensor([  15, 1649,  314,  717, 9569,  428], device='cuda:0'),
#   tensor([  16, 1081,  262, 3670, 1139,   11], device='cuda:0'),
#   tensor([   15, 15035,  1845,   709,  3691,    13], device='cuda:0'),
#   tensor([   15, 11259,   262,  2863,   284,  3551], device='cuda:0'),
#   tensor([  16,  314,  716,  407,  281, 7244], device='cuda:0'),
#   tensor([   16, 12168,  2745,   736,   314,  2626], device='cuda:0'),
#   tensor([   16,   366, 22648,   290, 15844,  3194], device='cuda:0'),
#   tensor([  16,  314, 1101,  407, 5385,  351], device='cuda:0'),
#   tensor([  15,  314,  373, 9670, 1576,  326], device='cuda:0'),
#   tensor([ 16, 770, 318, 530, 286, 262], device='cuda:0'),
#   tensor([   15,   371,  6680,   362,   357, 18946], device='cuda:0'),
#   tensor([  15,  383, 7205,  287,  428, 3807], device='cuda:0'),
#   tensor([   15,  1881,   286,   262,   749, 18078], device='cuda:0'),
#   tensor([   16, 21939,    11,   555, 47914,  3435], device='cuda:0'),
#   tensor([   16, 18181,   329, 25937,   617,  3621], device='cuda:0'),
#   tensor([  16,  314,  423,  550,  428, 2646], device='cuda:0'),
#   tensor([  16,  314,  373,  845, 6568,  618], device='cuda:0'),
#   tensor([ 16, 770, 318, 530, 286, 883], device='cuda:0'),
#   tensor([  15, 5613, 5961,  318,  477, 7334], device='cuda:0'),
#   tensor([   16,   314, 12546,   351,   262,   545], device='cuda:0'),
#   tensor([  16,  770, 3807,  318, 4998,   13], device='cuda:0'),
#   tensor([ 15, 314, 836, 470, 892, 314], device='cuda:0'),
#   tensor([  16, 4900,  314, 6635, 4236,  351], device='cuda:0'),
#   tensor([  16,  314, 1053, 1775,  428, 3807], device='cuda:0'),
#   tensor([   15,   317, 20105, 10997,   416,   262], device='cuda:0'),
#   tensor([  15, 1320,  338,  703,  314,  373], device='cuda:0'),
#   tensor([   16, 25998,    79,  4733, 31136,  2466], device='cuda:0'),
#   tensor([   15,  1318,   338,   617,  3621, 31068], device='cuda:0'),
#   tensor([  15, 1400,  530,  318, 1016,  284], device='cuda:0'),
#   tensor([  16,  383,  938,  357,   40, 1975], device='cuda:0'),
#   tensor([  16, 1002,  345,  389,  257, 4336], device='cuda:0'),
#   tensor([  15, 4900,  257,  925,  329, 7862], device='cuda:0'),
#   tensor([  16, 7477,   11,  257, 2646,  546], device='cuda:0'),
#   tensor([  16, 7477,   11, 8781,  651,  530], device='cuda:0'),
#   tensor([  15,  314, 1053,  655, 5201, 4964], device='cuda:0'),
#   tensor([  15,  770,  468,  284,  307, 3336], device='cuda:0'),
#   tensor([   16,  1312,   815,   423, 19169,   326], device='cuda:0'),
#   tensor([  16,  632,  338, 1327,  284, 1234], device='cuda:0'),
#   tensor([  16, 6035, 9232,  550,  262, 2785], device='cuda:0'),
#   tensor([  15,  770,  905,  318,  546, 1115], device='cuda:0'),
#   tensor([  15,  428,  318, 2646,  318, 2192], device='cuda:0'),
#   tensor([  15,  428,  416, 1290,  530,  286], device='cuda:0'),
#   tensor([  16,  314, 2074, 3589,  284,  307], device='cuda:0'),
#   tensor([   15, 22596,   422,   852,  2823,   588], device='cuda:0'),
#   tensor([   15, 12429,  4303, 49713,  1137,  1174], device='cuda:0'),
#   tensor([   16,  1703, 25440,  1024,    46,   824], device='cuda:0'),
#   tensor([  16, 2773,  743, 1254,  326,  262], device='cuda:0')],
#  [tensor([12696,   938,  1755,   329,   262,   362,   358, 16853,   523,  1312,
#             460,   470,  3938,  2423,   428,  2646,   780,   314,   716,  2407,
#            2407,   257,  4336,   360,  1847, 18227,    13, 10889,    11,   314,
#             373, 11679], device='cuda:0'),
#   tensor([  257,  1049,  4731,    12, 21397,  2318,   290, 38645,   281,  1593,
#            4046,    13,  1318,   338,   428,  3608,  3496,   810,   345,  1949,
#             284,  1107,  3049,    12, 11813,   329, 16187,   866, 48681,   290,
#             788,   366], device='cuda:0'),
#   tensor([  355,   284,  1283,   523, 16425,    13,  4042,   661,  2342,   428,
#            2646,   780,   484,   760,  2147,   546,   317,  5296,   832,   640,
#           29847,  1671,  1220,  6927,  1671, 11037,  8061,   651, 23384,   329,
#             663,   898], device='cuda:0'),
#   tensor([  257, 35778,  2646,    13,  5600,   262,   625, 14451,  1466,   389,
#            7818,   329,   262,   636,   407,  3052,  8188,   389, 21530,    13,
#             289,  3020,   475,   314,  8288,   340,  1682, 29847,  1671,  1220,
#            6927,  1671], device='cuda:0'),
#   tensor([  940,    13,  9576,  3595, 10470,    13,  2773,  7188,  1283,  3190,
#             753, 40819,  1843,    26,  1854,   389,   618,   484, 11173,    13,
#            2773,  8188,   389,  2823,   422,   262,   845,  3726,    11,   543,
#             655,  1595], device='cuda:0'),
#   tensor([ 5041,    11, 14918,   373,   257,  2045,  3516,  1909,    13,   679,
#            3382,  2130,   284,  6901,   428,  3807,   355,   366,  9410,   680,
#             526,  1279,  1671,  1220,  6927,  1671, 11037, 13898,    11,   428,
#            3807,  4120], device='cuda:0'),
#   tensor([  503,   319,   597, 12661,  1517,   314,   460,   892,   286,    11,
#           10443,  1012,  1324,  3503,  1106,   632,   373,   281,  2562,  5287,
#              11,   290,   281,  3489, 18344,   572,   286,   257, 48345,  7112,
#           19146,   337], device='cuda:0'),
#   tensor([  286,   262,  7706,  5937,    13,  3954, 10281,   389,   257, 13516,
#             286,  2026,   338,   290,  3126,   338, 10359,  1725,   351,   257,
#           39859,   494,  1855,  5119,  1611,   286, 20868,   438,    64,  3516,
#             508,  2058], device='cuda:0'),
#   tensor([ 3836,  3022,   319,  6518,  7758,    85, 34454,   512, 10134,   275,
#            8158,   296,   647,  3240,   318,  1363,   284,   257, 19029,  8530,
#             448,  2644,  1312,  1612, 19424,   703,   460,  1312, 43046,   423,
#             517,  2173], device='cuda:0'),
#   tensor([   11,   428,  2331,   284,   423,  4632,  3377,   663,  1637,   290,
#             965,  2150,  1978,   845,  1877,  4466,  3048,    13,  4042,   286,
#             262,  5621,   357,   273,  5621,     8,   389,  1107,  1468,    11,
#             290, 13510], device='cuda:0'),
#   tensor([   11,   475,  2147,  2041,   986,   383,  1266,   636,   318,   262,
#           14397,  3715,   351,   262,  1976,  2381,  1431,   336,   261,   368,
#            2040,    68,  2095,  5170,   607,   475,   607,  9955,    13,   887,
#             284,   645], device='cuda:0'),
#   tensor([  318,   530,   286,   262, 36090,  6386,  7328,  1312,  1053,  1683,
#            1775,   287,   616,  2104,  1204,    11,   290,   284,   307,  5508,
#             340,   373,   845,  1178,   286,   262,  1661,  1312,   373,  4684,
#             284,  2342], device='cuda:0'),
#   tensor([  338,   749,  4388,  2646,   290,     7,    40,  4236,   326,   616,
#           10946,   546,   262, 49798,   547,   262,  2642,   530,     8,   780,
#             428,   318,  6159,  1107,   257,  9961,  4249,   257,  1612,   494,
#             422,   262], device='cuda:0'),
#   tensor([  257, 13510,  5118,   379,  1755,    11,   788,   345,  1244,   355,
#             880,   779,  3336,  5550,  1503, 17254,    32,  5357, 23703,  2751,
#           22470,   532, 14563, 41087, 11176,  2539, 10850,    13, 10889,   340,
#            3360,  3073], device='cuda:0'),
#   tensor([  532,   281,  4112,  1276,   766,  6801,  2646,   597,   783,   393,
#             329,   262,  1613,  5996,   812,    13,  3362,  4643, 38979,   574,
#             290, 20894, 28515,  2731,  1234,   503,   428,  2646,   287, 24822,
#            7325,  2842], device='cuda:0'),
#   tensor([42156,   543, 48754,   845,   880,   351,   262,  2095,   532,   314,
#             655,  1842,   340,   618,   673,   373,  4001,   284,  1494,   262,
#           11868,    13,   632,   550,   262,  1245,   286,  4478,   510,    11,
#             287,   257], device='cuda:0'),
#   tensor([ 3126,   338,   290,  1033,  5388,    12,    69,  7626,   852, 43062,
#              12, 20286, 15192,   284,   477,  9337,   287,   663,  1903,  1528,
#              13,   314,   373,  4642,   287,   262,   502, 16588,  8227,  7215,
#              37,  2135], device='cuda:0'),
#   tensor([  284,  2298, 33834,  5468,   286,   262, 12490,  3091,   290,   262,
#             995, 37180,   284,   766,   262, 12490,  1339,    13,   383,  8379,
#             286,   262,  4048,  2095,   287,  3877,   338,  4934,  3670,    11,
#             366,   464], device='cuda:0'),
#   tensor([24251,   276,   329,   502,   284,  5461,   262,   717,   642,  3951,
#             286,   262,  3807,    11,   290,   612,   389,   691,  1511,  3951,
#            2861,    11,  2035,   835,    11,   340,   373,  1474,   262,  4220,
#             286,   262], device='cuda:0'),
#   tensor([  287,   262,  4019,    82,    11,   314,   423,  1464,  8288,   262,
#            3807,   366, 25234,  6252,  1600,   290,   373,   845,  6568,   788,
#             284,   766, 27633,  7733,   503,   326,   373,   922, 20122,   290,
#            8531,  3228], device='cuda:0'),
#   tensor([  383, 17389,   422,   616,  1903,  9963,    13,   314,   991,  7634,
#           11688,   749,   286,   262,  6877,   364,   284, 41396,    88, 15016,
#              11, 47107,    11, 14657,    88, 14835,  3150,   290,   772, 24766,
#              13,   770], device='cuda:0'),
#   tensor([ 4960,  2495,  6918,    13, 13745,   414,   290,  5761,   635,    13,
#             887,   262, 37960,   286,   428,   905,   318,   366, 31416,   278,
#             262,  4317,   338,  5157,  9313,    27,  1671,  1220,  6927,  1671,
#           11037,     6], device='cuda:0'),
#   tensor([  584,  2523,  4145,  1290,  3128,   736,   284,  7169,    13,   383,
#             734,   661,   508,   932,  1150,   262, 14142, 10530,   389,  2506,
#             338,  4004,  8786,    25, 18935,   290, 21776, 44677,    13,  3412,
#           32722,  3864], device='cuda:0'),
#   tensor([ 2147,   517,   621,   257,  2646,  1524,  3645,  3807,    13, 11391,
#             546,   340,   318,  1760,   351,   257, 16931,  4676, 29847,  1671,
#            1220,  6927,  1671, 11037,  2215,   314,   717,  3285,   262,  3670,
#             286,   428], device='cuda:0'),
#   tensor([  286,  3807,    11,   257,  1103,  6273,   286,  2099,   286,  2646,
#            3918,   286,   867,  7328,    11,   661,   286, 15874,  9337,   290,
#           21804,   329,   262,  1468,  2842,    13,   770,   373,   257,   717,
#            2494,  2646], device='cuda:0'),
#   tensor([ 1755,   287, 10123,  9621,   290,  1392,  3190, 25669,   656,   340,
#              13,  1881, 14532,   706,  1194,   356,   389,   287,  1842,    13,
#           16766,  1576,  1139,   262,  3437,   546,   262,  7205,   286,   262,
#             734,  1388], device='cuda:0'),
#   tensor([  329, 11336,   360,  2763, 10823,    11,   290,   329, 18653,  6656,
#             367,   667,    13,  4042,   286,   262, 45176,   389,  1107, 12361,
#              13,  5455,   286,  1619,  1075,   656,   644,  1838,   257,   922,
#           18528, 31423], device='cuda:0'),
#   tensor([  597,   530,  1448,   286,   642,    13,   940, 13178,   428,  3807,
#             477,   357,  2949, 30783,    11,  1881,  2907,     8,   366,    40,
#           22163, 28683,     1,   318,   262,  2818, 24655,   326,  1838,   428,
#            3807,   790], device='cuda:0'),
#   tensor([  286,   262,  1266, 13445,  1683, 10457,   986, 39239,   339,   743,
#             407,  5052,  7328,  1587,   239,   475,   339,   338,   530,   286,
#             262,  6000,   286,   465,  1611,  5145,  7273,   325,    11, 15962,
#             290, 11856], device='cuda:0'),
#   tensor([ 1204,   357,    67,   567, 41101,   286,  7077,     8,   284,  1037,
#           12242,  5953,   357, 20850, 10654,     8,  6758,   287,   465,  1492,
#           19934,  1693, 29847,  1671,  1220,  6927,  1671, 11037,    32, 25906,
#           32695,   422], device='cuda:0'),
#   tensor([ 1607,   257, 30314,   286, 23842,  7974,   287,   428,  3807,   503,
#             286,   257,  2565,   286, 12990,   502,   988,    12,   645,    11,
#             428,   318,  2147,  1342,   621,   257,   552, 22220,  7269, 11868,
#           29847,  1671], device='cuda:0'),
#   tensor([    1, 42078,   286,   366, 11002,   913,   569,   844,   268,  1600,
#             262, 14489,  3195,  3227,   286,   262,  2968,  2646,    11,   366,
#              45,   721, 25986,  1911,   383,  7110,    25,  4930,  5582, 23557,
#            6554,  1074], device='cuda:0'),
#   tensor([ 1775,   262,   717,  3807,   257,  3807,  1312,  1053,  1775,    11,
#             290,   314,   691,   655,  4978,   428,   530,   780,   340,  2492,
#             470,   319,  3195,  1865, 29847,  1671,  1220,  6927,  1671, 11037,
#            1026,   338], device='cuda:0'),
#   tensor([ 2423,   617,   286,   262,  1353,   317, 43480,  6918,    13,   314,
#             423,   587,  4642,   994,   532,   477,   625,   262,  2585,   532,
#             422,   807,   284,  9722,   718,   812,    11,   290,   314,  1053,
#            1775,   867], device='cuda:0'),
#   tensor([ 2497,   262,  3807,    11,   428,   318,   749,  1884,   262,   691,
#            1738,    13,   632,   338,   530,   286,   262,  3016,   477,  4814,
#            8188,    13, 10889,   340,   338,   257,  3206, 10997,    11,   357,
#            8499,  1719], device='cuda:0'),
#   tensor([  262,  3437,   286,   428,  2646,    13,  1892,  1165,   867,   389,
#           10457,   996,    11,   611,   340,   373,  1744,   357,  4480, 11781,
#            2785,     8,   612,   338,   281,   555,  1077,  2434,  3463,   319,
#             616, 12450], device='cuda:0'),
#   tensor([  257,  1049,   347,  3807,   611,   340,  2492,   470,   262, 29262,
#             286,   642,  1751,  4970,    13,  1318,   547,   645,  5895,   286,
#             597,  3685,   393,  1997,    13,   383,  1644,  1422,   470,  6324,
#             284,   262], device='cuda:0'),
#   tensor([ 1752,     0,   314,   991,  1283,   284,  1064,   340,   257, 23056,
#            1998,    11,   772,   611,   340,  2753,   617,  7325,   670,   416,
#            1854,   290, 24601,   257,  1178,  3131,  8059,   329,   262,  8761,
#              13,   314], device='cuda:0'),
#   tensor([ 2904,   475,   550,   655,  5071,   616,  4004,  4508,    12,  3605,
#            4538,  1097,    11,   262, 16526,   402,    19,    13,   632,   338,
#             588,  5442,   262,  5675, 23832, 29847,  1671,  1220,  6927,  1671,
#           11037,    40], device='cuda:0'),
#   tensor([21090,  2196,   286, 14156,  6597,  5112,   326,  3544, 10457,   384,
#             363,   282, 17090,   287,   790,  5739,    13,   383,  3048,   389,
#             845, 14169,   290,   345,   460,  1254,  3511,   736,   287,   262,
#           21258,  3715], device='cuda:0'),
#   tensor([   47,    13, 37655,   338,   366,    36,   535, 36027,   459,   274,
#               1,   743,   307,  1844, 35022,    11,   475,   340,   338,  2192,
#           13139,    12, 14662,   362,   287,   262,   976,  2756,  2837,   355,
#             262,  2656], device='cuda:0'),
#   tensor([   35,   695,     8, 11534,   329,   257,  1693,   986,  1525,   257,
#            3595,   965,   931,   316,    11,   508,   318,   407,   465,  6678,
#            2116,    13, 18208,   308,  3775,  2897,   281, 19827,  3721,   355,
#             880,   355], device='cuda:0'),
#   tensor([  513,    11,   780,   286,   262,  2646,   338,     7, 42773,    11,
#             262,  7205,  3730,   828,  1201,   340,   550,  1913,  8425, 13460,
#             290,  3968,    11,   290,   340,   318,   523,  5901,   351,  1913,
#            1981,  5400], device='cuda:0'),
#   tensor([  355,   257,   513,    11,   475,   938,   362,   287,   477,  1279,
#            1671,  1220,  6927,  1671, 11037,   464,  1917,   767,    14,   940,
#             318,   326,   340,   318,   257,  1981,   905,   351,  3737,  1315,
#             661,    11], device='cuda:0'),
#   tensor([ 7342,  3294,  6300,    13,   770,   530,   318, 14262,    11,   262,
#            7205,   318,   845,  3595,    13,   632,   318,   845,  3105, 44756,
#             351,   257,  1256,   286, 42047, 11800,   774,    13, 15323,   340,
#             264,  1611], device='cuda:0'),
#   tensor([ 1254,   326,   314, 24241,   656,   428,  2646,   290,   373, 46814,
#            1143,   290, 33720,   416,   340,    13,  1881,   286,   616,  4004,
#            5788,   547,   402, 21006,  5272,  6484,   290,  9077, 18281,  3287,
#              67,   287], device='cuda:0'),
#   tensor([16365,    12,    82,  1694,  3807,   561,   307, 30785,   338,   475,
#             340,   338,   407, 14084,  3306,  1201,   314,  1842,   262,  6000,
#             286,   262, 37475,    13, 16805,   314,   691,   760,   286,   617,
#             286,   262], device='cuda:0'),
#   tensor([    1,   318,   530,   286,   262,  1266,  6918,   314,  1053,  1683,
#            1775,    13,   383,  7205,   373,   764,  2811,    13,   314,  1842,
#            1793,    13,  3852, 15478,    88,  7263,    11,   663, 35704,   523,
#            2726,   340], device='cuda:0'),
#   tensor([ 8830,   546,   257,  3504,  9722,  9214,  6972,  6260,  3597,   290,
#            4964,   262,   366, 11274,     1,  2223,  6918,   366,    66,   430,
#           14097,     1,  8830,    82,   290,   852,  9431,    13,   383,  3807,
#             318,   546], device='cuda:0'),
#   tensor([  356,   389,   477,  7954,    13,  1675,   307,  7954,   351,  1223,
#            4325,    13,   775,   389,   477, 19283,   780,   356,   423,   884,
#           22029,  7445,    13,  1675,   307, 19283,   780,   356,   460,  1577,
#            1204,   736], device='cuda:0'),
#   tensor([ 3517,  3794,    11,   314,  1101,   407,  6655,   326,  1243,  1422,
#             470,   467, 10315,   338,   835,    13,  1119,  1422,   470,  1645,
#             780,   484,  1422,   470,   765,   284,  1106,   355,   530, 46914,
#            4367,   366], device='cuda:0'),
#   tensor([ 8662,    11, 41168,   287, 11225,   318,  2192,   262, 38889,  3807,
#             314,  1053,  1683,  1775,    11,   521,  2308,    11,   611,  1683,
#             612,   373,   257,  2081, 29932,   366,  1108,  1600,   270,  1276,
#             423,   587], device='cuda:0'),
#   tensor([ 2472, 46594,    13,   314,  1842,   705,    32,  1448,   286, 17366,
#            2877,   287,   262,   705,    33,     6,   636,    11,  4964, 25708,
#             290, 36254,   379, 24638,    13,   314,  1043,   262,  7110,  4457,
#            1913,   290], device='cuda:0'),
#   tensor([  257,  1029,  7955,   319,  8959, 43832,    11,   475,   314,   836,
#             470,  1283,   284,  3359,   340,   881,    13,   632,   318,   257,
#            2646,  1912,   319,   257,  1621,   416,  3271, 30785, 23023,    11,
#             290,   314], device='cuda:0'),
#   tensor([11037,    40,   717,  2497,   262,  2646,   530,  6180,   319,   262,
#            1957,  3195,  1430,   366,  7575, 13524,   364,  1600,   543,  3417,
#             262,  2646,   319,   262,  4417,   355,   257, 39867,    11,   366,
#           11227,  1326], device='cuda:0'),
#   tensor([ 373, 5032, 2759,  925,   13,  383, 1621,  290, 2546,  750,  407,  523,
#            881, 1487,  351,  262, 2223, 6918,  355,  986,  428,  561, 2048,  307,
#           1900,  355,  262, 5290, 2223, 3807,  286,  477], device='cuda:0'),
#   tensor([ 3223, 31535,   318,   925,   351,   257,   845,  3734,  3350,   290,
#            2407,   257,  7110,    13,  3862,  3454, 42286,   318,   262,   983,
#             287,   262,  7205,  5011,   532,   262,  1266,   636,   318,  4753,
#             618,   262], device='cuda:0'),
#   tensor([  318,  1690,   262,  1738,  1521,   257,  3807,   318,   523,  1690,
#             257,  1363,  2650,    13,  2080, 13957,   284,   262,  3670,    11,
#             340,   655,   743,  1107,   307,   262,  3670,   326,    11,   616,
#             379,   262], device='cuda:0'),
#   tensor([  529,  3970,   351,   257,   922,  2569,   326, 11984,    12, 25782,
#             750,   407,   423,   284,   466,   351,  1492,  7208, 29847,  1671,
#            1220,  6927,  1671, 11037,  1870,   257,   266, 21963,   306,   458,
#            5088,   278], device='cuda:0'),
#   tensor([ 1422,   470,  1210,   340,   572,   706,   362,  2745,    13,   383,
#            7464,   460,   307,   922,    13,   383,   717,   352,    12,    17,
#            8188,   389,  1107,   922,    13, 10127,   393,   407,   326,   318,
#            1266,  6100], device='cuda:0'),
#   tensor([  703,   284,  6901,   428,  3704,   286, 13913,    13,   314,   373,
#             845, 11679,   287,   340,   523,   881,   314,  9658,  2691,   284,
#            2198,   340,   503,    13,   314,  4398,   470,  1775,   262,  8631,
#            3223, 10997], device='cuda:0'),
#   tensor([  468,   407,  1464,   587,  2164,  2286,   351,  3895,  4129,  7328,
#              11,   475,   314,   635,   373,   407, 10607,   351,   428,   530,
#              13,  8832,   360,  1252,   494,   318,  1049,   287,   428,   530,
#             355,   262], device='cuda:0'),
#   tensor([17574, 20214,     1,   319,  5581,   287,  4343,  2011,  2612, 11173,
#             618,   314,  1807,   477,   262,  3435,   287,   428,  2646,   714,
#             307,  1775,   757,   290,   757,   780,   314,  6151,   366,    39,
#            4595,   707], device='cuda:0'),
#   tensor([  286,   262,   749,  7189,  7328,   314,   423,  1683,  1775,   475,
#             262,  6317,   286,   883,   508,  3432,   502,   416,   262,  1637,
#             373,   845,  2089,    13,  7214,   262,  3452,   791,  1640, 42182,
#               0, 16527], device='cuda:0'),
#   tensor([   11,   530, 24141,    11,   787,  2405,   656,  1223,  2495,  3499,
#              11,   475, 22029, 29847,  1671,  1220,  6927,  1671, 11037,   464,
#            5199, 10343,    85,   439,   640,  2278,   373, 10457,    11,   262,
#            4141,   389], device='cuda:0'),
#   tensor([21908,     8,   416, 22162, 39447,  1706,  4889, 41788,  2638,  1378,
#            2503,    13,    74,   586, 11510,   970,    13,  6888,    14, 21952,
#              62,   452, 10076,   338,    14,  5031,    12,  4018,  3609,    14,
#            1954,  1415], device='cuda:0'),
#   tensor([  329, 12659,    82,   588,  2619,  3217,   290,  5616, 20400,    11,
#            3437,  8982, 26812,   368,  5341,   257,  2415,   508,  2925,   284,
#            3996,  1088, 15896,   351, 48172, 33301,    13,  1649, 22637,  3443,
#           34267,    11], device='cuda:0'),
#   tensor([  616,   477,   640,  4004,  7328,    13,   383,  7205,  2810,   416,
#             262,  2187, 34549,   318,  1353, 29838,   284,   307,  1654,    13,
#            7406,  5664,   314,   373,   287, 10953,   286, 29894,    11,  6225,
#            5179,   286], device='cuda:0'),
#   tensor([  336, 24275,    26,   392,  1169,   835,   262,  5462,  6324,   284,
#            2994,   290,  8270,  5306,  6267,    13,  1169, 45076,   373,   612,
#            1377,    86,  8623,   913, 31068,   329,   257,   336, 24275,    13,
#            1659,  1781], device='cuda:0'),
#   tensor([  910, 29847,  1671,  1220,  6927,  1671, 11037,  5779,   986,   314,
#             760,   546,   287, 24040,   986, 18689,   326,   338,  3446,   644,
#             314,   373,   546,   284,   910,   986, 14190,  2089,   750,   484,
#            2051,   408], device='cuda:0'),
#   tensor([  287,  1502,   284,   766,   703,   340,   561,  8996,   284,   584,
#            7328,   319,   616,  4947,    13, 35784,   286, 16306,   318,  2407,
#             257,  6380,   284,   502,    13,  5779,    11,  5562,   338,   340,
#              11,  4360], device='cuda:0'),
#   tensor([ 2646,   329,   883, 25776,     6,  1751,   618,   674,  6802,  1146,
#           19514,   780,   314,   760,   612,   338,  2147,  1107,   826,   546,
#            1223,   484,   466,   284,   787,   340,  1242,    11,   475,  1566,
#             616,  3656], device='cuda:0'),
#   tensor([ 1176,   290,  1175,   319,  4486,    11,   262, 12653,  6087,   286,
#            1692, 15499,    11,  6754,  2356,   290, 41439,  1918,   318,  2048,
#             257, 30669,    13,  7875,  2687,  1775,   517, 34557,   621,   428,
#            7464,   287], device='cuda:0'),
#   tensor([  477, 29847,  1671,  1220,  6927,  1671, 11037,   464, 34549,  3350,
#              11,   262,  8173,   286,  7325,  5408,    11,   262,  8173,   286,
#            4226,  7585,    11,   290,   262,  1336, 32483,   286,  3227, 27505,
#             790,  2656], device='cuda:0'),
#   tensor([43832,   355,   257,  4941,   329,   257,  7684,   286,   812,    13,
#             317,  3195, 15602,   428,  3035,    13,   314,   635,  1908,   257,
#            2661,   329,   257,  1492,    11, 20633,   351,   257,  9577,   546,
#             326,   968], device='cuda:0'),
#   tensor([  314,  1101,  3221,  8788,   351,  1877,  4466,  7328,    13,  2011,
#            1790,  4466,   750,  1088,   720,   940,    11,   830,   351,   257,
#           38104,  2646,   290,   257,  2297, 33196,  2646,    13,  1320,  2925,
#             329,   517], device='cuda:0'),
#   tensor([  318,   720,    17,    13,   357, 14585,     8,   318, 17700,   306,
#            2089,    11,   475,   314,  1053,  3066,   407,   284,   772,   892,
#             546, 46743,   606,   284,   423,  7471, 29847,  1671,  1220,  6927,
#            1671, 11037], device='cuda:0'),
#   tensor([  533,  2230,   379, 40870,  9961,    11,  1844,   351, 47456,   326,
#            3807, 14429,   389,  1804,  3807,  1642,   290,   645,  1103,  2095,
#            2478,   329,   428,   530,    13,  2329,  6044,   340,   475,   612,
#             338,   257], device='cuda:0'),
#   tensor([  314,  2497,   428,  3807,    11,   314,   373, 36250,  7016,   284,
#            2342,    13,  1279,  1671,  1220,  6927,  1671, 11037,  2953,   717,
#             618,   314,  2497,   262, 12531,  4286,   286,   257, 43973,  6565,
#            6483, 36435], device='cuda:0'),
#   tensor([   11,   340,   338,   407,   329,   262,  1109,   326,   340,   373,
#             262,   749, 14262,  2646,   314,   550,  1683,  1775,   357,  4360,
#             340,   373,    13, 27864,   326,   546,   788,    30,  6023,  3950,
#            3195,  4471], device='cuda:0'),
#   tensor([ 2084,    11,  1222,   996,    11,   314,  1422,   470,   892,   340,
#             373,  1844, 18824,    11,   314,   815,   423,    13,   632,   373,
#             257,  4735,  2342,    11,   329,   749,   286,   262,  4136,    13,
#            9576, 28175], device='cuda:0'),
#   tensor([ 3807,   314,   373,  1239,  6886,   284,   257,  3807,    13,  2102,
#              11,   790,  3807,   314,  7342,   329,   257,   981,   373,   530,
#             286,   262,   749, 12361,   284,  1683,  1645,   284,   502,    13,
#             314,   373], device='cuda:0'),
#   tensor([  428,  3807,   318,  4988,  3675,   720,   940,    13,   314,   460,
#            1833,   326,   611,   345,   836,   470,   588,   379,  1551,   530,
#            8133, 15616,   736,  1542,   812,  2084,    11,   530,   286,   616,
#           12507,  7205], device='cuda:0'),
#   tensor([19097,   375,   337, 28082, 20951,  3811,  3617,    11,  1350, 13030,
#             340,   338,   407,  2861,   262,   640,    13,  1400, 31136,    13,
#              27,  1671,  1220,  6927,  1671, 11037, 11230,  3727, 20832,   376,
#            9306, 31742], device='cuda:0'),
#   tensor([  290,  1277,   588,   257,   922, 10873,  4623,  1693,    13,   815,
#             787,  1088,   720,    23,    11,   830,   287,  2646,    13,  5288,
#             604,  5788,    13,  4418,  5486,  3594,   290,  4141,   318,   407,
#           10909,    13], device='cuda:0'),
#   tensor([ 3837,  1754,  4336,   475,   314,   373,   845, 24562,   379,   428,
#             530,    13,   679, 17948,   502,  1497,   351,   465,  1943,   290,
#             511,  7205,  2627,   772,  1365,    13,   383,  2187,  2646,   318,
#            6454, 44207], device='cuda:0'),
#   tensor([  954,   286,   703,   867,  1661,   314,  7342,   428, 12361,  3807,
#              13,   314,   716,  1464, 14176, 20410,   351, 23274,    11,   475,
#             314,   655,   460,   470,  1577,  1997,  1497,  5115,   428,  3807,
#             290,   663], device='cuda:0'),
#   tensor([  329,   262,  3800,  2712, 12490,    13, 13435, 10047,    12, 14664,
#             605, 12834,    11, 19558,  1360, 26617,  8137,  5855,  5246,    13,
#           19219,  8050,  1600,   366,  5779, 22025,   519,   274,     1,   290,
#             366,   464], device='cuda:0'),
#   tensor([  597, 30702,  1719,  1775,   428,  3807,   475,   284,   307,  5508,
#              11,   356,   477,  3111,   523,  1327,   326,   706,  4964,   340,
#              11,   356,   547,  4684,   284,  1975,   326,   612,   547,  8563,
#             287,   340], device='cuda:0'),
#   tensor([ 314,  373,  379,  257, 2008, 3650,   11, 6149,  530,   11,  290,  340,
#           5284,   13,  314,  373, 1107, 6655,  379,  262, 3081,   11,  475,  706,
#           4379,  340,  532, 1807,  340,  561,  307, 8258], device='cuda:0'),
#   tensor([ 1178,  6918,   326,  7866,  1626,   262,  3624,   444,    13,  1114,
#            2687,   357,   259,   616,  6641,     8, 23840,   284,  3095,    12,
#            1238,   400,    12, 14792, 22041,    11,   340,   743,  1283,   588,
#             257,  6792], device='cuda:0'),
#   tensor([    8,    27,  1671,  1220,  6927,  1671, 11037,  7571, 39898, 10568,
#           15774,  2761,   287,   511,  1029,  1524,    13,   383,   717,   318,
#             262,   761,   284,  7808,   287,   355,  1444,   329,   416,   399,
#            5330, 37198], device='cuda:0'),
#   tensor([  373,   257,  6833,    13,   314,   716,   257, 15800,  5141,   508,
#           10408,   262,  5337,    11,   262,  3590,  7352,   286, 10997,   290,
#            9280,    13,   314,  6151,   262, 10544,   407,   379,   477,    13,
#             314,  1183], device='cuda:0'),
#   tensor([ 6918,   314,  1053,  7342,   329,   262,   938,  3478,   812,    13,
#           16902,  9544,  2848,    11,   508, 32466,   468,  2716,   351,  5850,
#           44963,   290, 24238, 28346,   318,   287,   428,  1263,  1738,   284,
#            2342,   428], device='cuda:0'),
#   tensor([ 1334,   588,  6181, 36062,    25,   407,  8258,   393, 28297,    11,
#             407,   284,   597,  2099,   286,  6754,  6817,    11,   612,   338,
#             407,   881,   262,  3807,   284,   307,  6825,    11,  2048, 12062,
#             287,   262], device='cuda:0'),
#   tensor([18105,   287,   262, 35030,    11,   428,  3807,   318,   407,   257,
#            3800,  3807,    13,   317,  1263,  4151,    11,  1402,  1182,   986,
#             439,   287,   477,    11,   340,   318,   407,   530,   286,   262,
#            1266,  8312], device='cuda:0'),
#   tensor([  319,   616,   569,  7998,   290,   373,   530,   286,   262,   717,
#             284,  2912,   611,   340,   468,  1997,   284,   466,   351,  1200,
#           18384,    13,   314,   373,   546,   284,  1577,   510,   788, 12120,
#             287,   262], device='cuda:0'),
#   tensor([ 3977,   327,  8056,   505,   357,   292,   366,   464, 16828,     1,
#            4768,  3175,   590,     8,  3724,   422,   257,  2612,  1368,   319,
#            2805,   513,  4372,    11, 25325,    13,   887,    27,  1671,  1220,
#            6927,  1671], device='cuda:0'),
#   tensor([ 6918,   810,   345,  2342,   329,   546,  1194,   734,  2250,   290,
#             788,  5409,   326,  9599,   508,   468,   407,  1775,   340,   481,
#             655,  1282,   736,    11,   287,   428,  1339,   406, 23638,  1855,
#           10076,    72], device='cuda:0'),
#   tensor([  510,    11,  2562,    13,   632,   338, 18916,   326,   772,   262,
#             636,   852,  3088,   262,   277,  5457, 12008,  1497,   262,  5386,
#             422,  4964,   340,    13,  3412,   996,   281, 24110,   357, 19585,
#            1879,   527], device='cuda:0'),
#   tensor([ 9945, 37823,   319,  4375, 10914,   284,   428,    11, 10914,   318,
#             523,  1327,   284,  1833,    13,  5599,   913,   355,  3683,  2569,
#            2558,  1072,  1838,   340,  5299,  1014,   517, 24479,  5299,  1998,
#            1290,   517], device='cuda:0'),
#   tensor([ 340,  318,  790, 1643, 1180,   13,  314, 6151,  340,  588,  314,  750,
#            618,  314,  373,  287,  978, 9246, 3247, 7964,  287, 8437,   13,  843,
#            517,  568,  618,  484, 2716,  340,  379,  262], device='cuda:0'),
#   tensor([ 1682,  8288,   428,  3807,   379,   477,   584,   621,   329,   262,
#            1714,  3715,    11,   543,   468,   587,  1760,   867,    11,   867,
#            1661,   878,    13,  8005,    33, 33076,   714,   423,  1760,   340,
#            4785,    13], device='cuda:0'),
#   tensor([  262, 15598, 28855,  5855, 25082,  5268,   654,  4943,  7447,   263,
#             318, 27909,   416, 14234,    64, 33237,  4457,   880,   257, 13516,
#             286, 14309,   415, 10038,   351, 20589,   306,  6149,   698,  3974,
#            1039,    13], device='cuda:0'),
#   tensor([  319,  8959, 43832,   867,   867,  1661,    11,   290,   269, 10277,
#             356,   477,  4236,    25,   428,  3807,   318,  2861,  4379,    11,
#           13284,  7803,    11,   290,  5000,   340, 16596,    13,   314,  2391,
#             460,   470], device='cuda:0'),
#   tensor([ 1049,  4186, 29147,   290,  7924,   416,  3852,  1236,  5857, 13671,
#               7,    43,   813,  6047,   737,  1639,   423,   257,  5802,  5802,
#             582, 37049,  4270,   519,     7, 18050,  1879,  4364,  4149,    82,
#             262,  4226], device='cuda:0'),
#   tensor([ 7725,   284,   766,   428,  2646,    11,   475,   991,  2227,   284,
#            2342,   340,    11,   475,   612,   373,  1223,   546,   428,  2646,
#             326,  4030,   502, 40112,  1513,    11,   290,  4030,   502,  3867,
#            2651,   287], device='cuda:0'),
#   tensor([10628,  2196,   416, 43050, 28616, 17202,  4303, 49713,  4877,  1174,
#             770,   318,   281, 10517,   300,  2049,   326,   314,  1053,  7342,
#             625,   290,   625,   618,   314,   373,   257,  5141,    13, 23080,
#             373,   655], device='cuda:0'),
#   tensor([  290,   617,  1049,  8674,    14,   529, 16746,  3033,    13, 13434,
#             913,   284,  2342,   262,  7110,   290, 17310,   319,   477,  2974,
#              13, 16190,  4206,   428,  3807,   318,  3049,  3867,    12,  5832,
#             655,   423], device='cuda:0'),
#   tensor([ 6487,   379, 39271,    13, 17869,  1312,  6991,    13,  3966,  1312,
#            1101,  1365,   621,   749,   661,   287,   616,   905,    13, 23181,
#             306, 14262,   290, 43973,    67,  3350,  2915,    11,   290,   257,
#            1109,   286], device='cuda:0'),
#   tensor([  925,     8,   287,   262, 47722, 36933, 26298,   286,  9961,   290,
#             314,  2314,  4313,   428,  2646,   284,   597,  2060,  4044,   357,
#              40,  1053,  1239,   587,  1498,   284,  1064,   257,  2646,   290,
#             355,   329], device='cuda:0'),
#   tensor([  286,   262, 12648, 12770,    11,   534,   845,  1884,   284,  2883,
#             428,  3807, 29847,  1671,  1220,  6927,  1671, 11037,  2953,   717,
#           16086,   428,  3807,  5238,   588,   257, 14276,  2277,   319,   511,
#            1633, 32569], device='cuda:0'),
#   tensor([ 3807,    11,   340,  4120,   284,   651,  1365,   351,  1123,  2423,
#              13,  4900,   262,  7110, 22960,  1997,  8502, 13267,   284,   466,
#             290,   407, 35160,   319,    11,   340,   338,   407,  8718, 12653,
#             393, 31363], device='cuda:0'),
#   tensor([  582,     0,  5433, 23550,    13, 13248,   306, 43286,    13,   317,
#            1256,   286,   340,  5609,  3435,   290,  3867,  1054,    71,   654,
#            1863, 29847,  1671,  1220,  6927,  1671, 11037,  1858,   389,  3435,
#             290,  7445], device='cuda:0'),
#   tensor([ 1517,   503,   286,   262,   835,    25,   379,   262,  3726,   286,
#            4019,   338,  9961,  7328,    13,   287,  4019,   338,  6918,   484,
#             547,   655,  3501,   510,   319, 14343,  5621,   290,  9616,  1263,
#            4466,  6918], device='cuda:0'),
#   tensor([  428,  3807,    11,   475,   986,    27,  1671,  1220,  6927,  1671,
#           11037,   464,  3350,   318,  1049,    11,   996,   484,  2291,   617,
#             286,   262,   517, 18078, 11255,   357, 18219,  7459, 32777,    11,
#            3813,  6784], device='cuda:0'),
#   tensor([21881,  2257,  3807,  1683,   925,     0,   314,   691,  1392,  1367,
#             290,   340,  2900,   503,   284,   307,   257,  6833,    13,  1002,
#            5689, 17154,   550,   991,   925,   734,  6918,   884,   355, 28693,
#           17654,   290], device='cuda:0'),
#   tensor([  884,   257, 13455,  3194,  2928,  3807,  2314,   466,   881,   523,
#             287,   616,  2951,    13,   612,   318,   262,  4203,   262,  1613,
#           14234,   373,  1234,  1978,   287,   257,  3600,    11,   290,   314,
#             373, 20536], device='cuda:0'),
#   tensor([  656,  2456,   703,  2089,   428,  2646,   318,    26,   314,   655,
#            7342,   340,   287,   257, 13766,    11,   290,   787,   645,  7457,
#             340,   318,   257, 22121, 12659,  2646,    13,   383,  7205,   318,
#             262,  1551], device='cuda:0'),
#   tensor([  284,   307,  1049,    11,   706,  4964,   607,   670,   329,   845,
#             890,  2278,    11,   475,  2427,   673,  1619,  1079,   656,   428,
#             336, 24275,    11,   290,  5201,   510,   655,  1576,   284,   787,
#             345,   892], device='cuda:0'),
#   tensor([  661,   508,   886,   510,  1972,   572,   319,  7722,   262, 18455,
#             338,  2910,    13,  3226,  1781,   477,  1440,  2046,    12,  3823,
#            3925,  4236,   284, 16075,   606,   656,   262,  9256,  1338,   292,
#            3341,   290], device='cuda:0'),
#   tensor([  407,   262,  2646,   284,  8996,   422,   262,  1336,  1492,    13,
#             887,   340,   373,  2342,   540,    13, 11391,   287,   262,  3807,
#            2714,   340,    14,   270,  1978,   287,   257,   835,    13,  1892,
#             691,   262], device='cuda:0'),
#   tensor([  262,   749,    11,   314,  1624,   284,   423,  1775,   837, 37572,
#            1022,  5621,   286,   362,   284,  2342,   319,   257,  5145,  2644,
#            1169,  1877,  4466,  2816,  2431,    11,   314,   373, 16318,  1497,
#             764,   968], device='cuda:0'),
#   tensor([  257, 43050,  6559,  6960,  4336,    13,   679,   750,   340,   329,
#            1811,   812,   287,   262,  1903,   284,  3095,  4317,   338,    11,
#             290,    11,  2592,   422,  9768,   284,  7795,    11,   925,  7328,
#             326,   547], device='cuda:0'),
#   tensor([ 3334,  3961, 33375,    11,   428,   373,   285,  3020,  1350,   366,
#              79,  8023,   262,  3061,  1911,   314,   892,   612,   714,  1844,
#             351,   257,  7709,  3350,   290,   763,   487,  2841,    13, 18181,
#             326,   428], device='cuda:0'),
#   tensor([ 1635,  4303, 49713,  1137,  1174,   520,   567, 13567,   546,  8598,
#             275, 24913,   389,  1103,    11,   290,   428,  3807, 21784,   606,
#             510,  7138,    13,   314,  9159,   326,   314,  3521,   470,  1975,
#             428,    11], device='cuda:0'),
#   tensor([  418,    11,   635,  1900,   355,   705,  3147,  6200,  3256,   318,
#             257,   880,  3562,    11,   880, 18976,   290,   880, 13134,  3218,
#            1683,  1201,   655, 11681,   262,   717,   734,   309, 42902,    12,
#            2213,  1077], device='cuda:0'),
#   tensor([ 983, 2125,  470,  510,  284, 1582,  597, 4919,  475,  428, 1464,  468,
#            284,  307,  530,  286,  616, 4004, 1830,    0,  383, 6323,  314, 4724,
#            318, 3595,   11,  262, 8722,  318, 2407, 2408], device='cuda:0')],
#  [tensor(0.2361, device='cuda:0'),
#   tensor(0.0897, device='cuda:0'),
#   tensor(0.8637, device='cuda:0'),
#   tensor(0.6986, device='cuda:0'),
#   tensor(-1.5705, device='cuda:0'),
#   tensor(-1.3563, device='cuda:0'),
#   tensor(1.7047, device='cuda:0'),
#   tensor(-0.6574, device='cuda:0'),
#   tensor(0.3040, device='cuda:0'),
#   tensor(-1.1880, device='cuda:0'),
#   tensor(-0.2111, device='cuda:0'),
#   tensor(2.2093, device='cuda:0'),
#   tensor(0.2947, device='cuda:0'),
#   tensor(-0.5515, device='cuda:0'),
#   tensor(2.6161, device='cuda:0'),
#   tensor(0.2676, device='cuda:0'),
#   tensor(-0.2665, device='cuda:0'),
#   tensor(0.1322, device='cuda:0'),
#   tensor(1.1709, device='cuda:0'),
#   tensor(0.3691, device='cuda:0'),
#   tensor(-0.2742, device='cuda:0'),
#   tensor(-0.2382, device='cuda:0'),
#   tensor(-0.7412, device='cuda:0'),
#   tensor(1.2126, device='cuda:0'),
#   tensor(1.1279, device='cuda:0'),
#   tensor(-0.9806, device='cuda:0'),
#   tensor(-0.6306, device='cuda:0'),
#   tensor(0.5219, device='cuda:0'),
#   tensor(1.6192, device='cuda:0'),
#   tensor(-0.0662, device='cuda:0'),
#   tensor(-1.5123, device='cuda:0'),
#   tensor(0.2082, device='cuda:0'),
#   tensor(0.6312, device='cuda:0'),
#   tensor(0.4815, device='cuda:0'),
#   tensor(0.7009, device='cuda:0'),
#   tensor(0.3556, device='cuda:0'),
#   tensor(1.0211, device='cuda:0'),
#   tensor(-1.5493, device='cuda:0'),
#   tensor(0.2142, device='cuda:0'),
#   tensor(-1.0224, device='cuda:0'),
#   tensor(0.8651, device='cuda:0'),
#   tensor(-0.1148, device='cuda:0'),
#   tensor(-0.4912, device='cuda:0'),
#   tensor(-0.4639, device='cuda:0'),
#   tensor(-1.3040, device='cuda:0'),
#   tensor(1.9995, device='cuda:0'),
#   tensor(-0.0072, device='cuda:0'),
#   tensor(0.1198, device='cuda:0'),
#   tensor(0.3135, device='cuda:0'),
#   tensor(-0.1842, device='cuda:0'),
#   tensor(0.2337, device='cuda:0'),
#   tensor(0.5238, device='cuda:0'),
#   tensor(1.7319, device='cuda:0'),
#   tensor(0.7528, device='cuda:0'),
#   tensor(0.6657, device='cuda:0'),
#   tensor(-1.4527, device='cuda:0'),
#   tensor(1.0528, device='cuda:0'),
#   tensor(0.4825, device='cuda:0'),
#   tensor(0.7373, device='cuda:0'),
#   tensor(-0.4522, device='cuda:0'),
#   tensor(-1.9681, device='cuda:0'),
#   tensor(-0.4205, device='cuda:0'),
#   tensor(0.8949, device='cuda:0'),
#   tensor(-0.8927, device='cuda:0'),
#   tensor(-0.0629, device='cuda:0'),
#   tensor(-0.1479, device='cuda:0'),
#   tensor(0.1160, device='cuda:0'),
#   tensor(2.2153, device='cuda:0'),
#   tensor(1.4302, device='cuda:0'),
#   tensor(0.7175, device='cuda:0'),
#   tensor(-0.8383, device='cuda:0'),
#   tensor(-0.4666, device='cuda:0'),
#   tensor(-1.4006, device='cuda:0'),
#   tensor(2.3989, device='cuda:0'),
#   tensor(0.1194, device='cuda:0'),
#   tensor(-1.0473, device='cuda:0'),
#   tensor(-1.3110, device='cuda:0'),
#   tensor(-2.3097, device='cuda:0'),
#   tensor(1.0412, device='cuda:0'),
#   tensor(1.8973, device='cuda:0'),
#   tensor(-1.6141, device='cuda:0'),
#   tensor(1.5978, device='cuda:0'),
#   tensor(0.8793, device='cuda:0'),
#   tensor(-0.1412, device='cuda:0'),
#   tensor(1.1603, device='cuda:0'),
#   tensor(2.2721, device='cuda:0'),
#   tensor(-2.2508, device='cuda:0'),
#   tensor(-0.1765, device='cuda:0'),
#   tensor(0.7819, device='cuda:0'),
#   tensor(0.1453, device='cuda:0'),
#   tensor(1.3899, device='cuda:0'),
#   tensor(0.2009, device='cuda:0'),
#   tensor(-0.2105, device='cuda:0'),
#   tensor(-2.1044, device='cuda:0'),
#   tensor(-2.1757, device='cuda:0'),
#   tensor(0.7728, device='cuda:0'),
#   tensor(0.3229, device='cuda:0'),
#   tensor(-0.0776, device='cuda:0'),
#   tensor(0.2905, device='cuda:0'),
#   tensor(-0.5040, device='cuda:0'),
#   tensor(1.8440, device='cuda:0'),
#   tensor(2.5567, device='cuda:0'),
#   tensor(0.2352, device='cuda:0'),
#   tensor(1.1082, device='cuda:0'),
#   tensor(0.5327, device='cuda:0'),
#   tensor(-1.7819, device='cuda:0'),
#   tensor(-1.5915, device='cuda:0'),
#   tensor(-0.2001, device='cuda:0'),
#   tensor(-1.2970, device='cuda:0'),
#   tensor(1.1263, device='cuda:0'),
#   tensor(-0.1996, device='cuda:0'),
#   tensor(-0.1358, device='cuda:0'),
#   tensor(-0.2448, device='cuda:0'),
#   tensor(-0.2094, device='cuda:0'),
#   tensor(-0.5500, device='cuda:0'),
#   tensor(-0.1387, device='cuda:0'),
#   tensor(1.7398, device='cuda:0'),
#   tensor(0.0933, device='cuda:0'),
#   tensor(-2.9948, device='cuda:0'),
#   tensor(-2.9014, device='cuda:0'),
#   tensor(0.1850, device='cuda:0'),
#   tensor(-1.5188, device='cuda:0'),
#   tensor(0.2906, device='cuda:0'),
#   tensor(0.2851, device='cuda:0'),
#   tensor(0.9704, device='cuda:0'),
#   tensor(0.3512, device='cuda:0'),
#   tensor(0.7375, device='cuda:0'),
#   tensor(1.6551, device='cuda:0')])

# %%
from trl import PPOConfig, PPOTrainer

config = PPOConfig(learning_rate=1e-5, batch_size=b)
trainer = PPOTrainer(config, model_ppo, model_ppo_ref, tokenizer_actor)

for i in range(200):
    trainer.step(*get_data())

    if i % 5 == 0:
        print(i)

        question, answer, reward = get_data()
        question = tokenizer_actor.decode(question[0])
        answer = tokenizer_actor.decode(answer[0])
        reward = reward[0].item()

        #0差评,1好评
        print(question, '->', answer, reward)

model_ppo.pretrained_model.save_pretrained('model/trl')
# Out:
# /root/miniconda3/envs/cuda117/lib/python3.10/site-packages/trl/trainer/ppo_config.py:207: FutureWarning: `PPOConfig` is deprecated and will be removed in the future. Please use `PPOv2Config` with `PPOv2Trainer` instead.
#   warnings.warn(
# /root/miniconda3/envs/cuda117/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:193: FutureWarning: `PPOTrainer` is deprecated and will be removed in trl v0.12. Please use `PPOv2Trainer` instead.
#   warnings.warn(
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# /root/miniconda3/envs/cuda117/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:273: UserWarning: No dataset is provided. Make sure to set config.batch_size to the correct value before training.
#   warnings.warn(
# 0
# 1 This movie is a metaphor -> , symbol of humanity. You see this azick. Lamidi are HUMILITATING. The image of some people is nothing without the symbols of life 0.47835201025009155
# 5
# 1 A comedy before it's ->  been over four years now. Brand (Mark Pritchard) does to all the crew, some acts, but most that gave him a rest arguably, the 0.9503517746925354
# 10
# 1 I must admit, at ->  that time, I didn't believe in that movie at all--especially hurtted by the time I was one who was crying. The name of these people is -0.4734441339969635
# 15
# 1 I couldn't stop laughing ->  all around this movie! -My Dallow achievements as a film is formula perfect -Irateargoing to say that most of my recent´s in the 0.48055729269981384
# 20
# 1 **SPOILERS A -> wear is usually looked at as a cut above Jungle any way you can say it. What was the most part of this LOT of films I have not had -0.4607374966144562
# 25
# 1 Film is vintage Heston ->  and fairly long either Iranian it uses guys on its awesome tamales, or American films I'll seegenthe this rolling hot chick in the environment, smiling, 0.8804137110710144
# 30
# 0 Aunt Cora had always ->  since been "in bridge." She even switched it's career...that being her ie Scary title...if you honestly got something rather like it ached better 0.2262800633907318
# 35
# 1 While the draw for many ->  tell was good, this is where the humor and the great film forum bopped a few of the media members. The only one that was amusing went on the -0.3264821469783783
# 40
# 0 This is a neat pre -> quel from Greek horror movies. Dragon is definitely a filled with that should collect in the Wars:Cemetery after the failure of basic original projects like Dusk of our -1.6114801168441772
# 45
# 0 Before commenting on the movie ->  itself- what effects it did in one moment was a fine extra. I have no one to consider this film and a World.. Like this one film has an -0.7179616689682007
# 50
# 0 I was looking forward to ->  this episode and felt that it would be of unmatched value installment. If you are looking for something similar or something decent, see this.<br /><br /> 1.569724440574646
# 55
# 0 I'm not a huge ->  fan of the very good teen greats that there are out there that everyone knows with or without a real time like yook in times, i was in school 0.009143251925706863
# 60
# 1 I never tuned into Me ->  as I was sleeping, so tonight I watched Lethal Weapon<br /><br />I really enjoyed the film, I don't especially watched the day or compare 1.488284945487976
# 65
# 0 I mean, really... ->  This "movie" surely class was the most derivative made in my life that day in the early '00s. The movie basically began with a mystery in comedy 0.866361141204834
# 70
# 0 In Moscow, the young ->  lawyer Jack�7 from Vienna, president of the Republic Pierre avbene Popularizerug Françal Å Muir vriend Ist Paul Laere -0.6078140139579773
# 75
# 1 Just to make one thing ->  clear...this movie just doesn't have three action plays...i watched this movie to see how it goes a few times. However, it never stops. your -0.8150375485420227
# 80
# 1 Top notch performances from the ->  beautiful Naomi Sheffer. Not long, but provocative, shaded only with breathtaking detail. Canopy<br /><br />Flipped around carrots with2 0.9927238821983337
# 85
# 1 I'm an admirer ->  of you. I've watched this frequently throughout the years and always do very little if I'm watching a movie in the middle of the night and I always have 1.1173679828643799
# 90
# 1 To say that the new ->  Carpenter Quality is right to me. I recently restored some of the scenes from the original 'Scary Movie' and now I was new to see it. I 0.24238444864749908
# 95
# 0 We all loved the first ->  shot of this (1995, corrected on video on the DVD case to later look undetected on this particular film - only that 2006 - there's actually a heck -0.18571047484874725
# 100
# 1 THIS IS NOT A CH -> ILL. It sure isn't among my favorites and would have been nominated for better followings but it is so awesome. The overwhelming smile that you get when you 2.477813243865967
# 105
# 0 Wow I can't believe ->  this one could get picked up Capra's store on-line just today Interestingly I thought it wouldn't be the guinea rip commercial but Channel 3 decided to 0.035031408071517944
# 110
# 1 This film story is bad ->  or as though it was realism. None of the characters are close to each other. None of their characters really exist as human beings yet act very true to humanity -2.2182159423828125
# 115
# 0 I would definitely recommend this ->  to fans who really... who knows it right from the get go? The plot is interesting and one of the first picks from the NSA(came back) -0.2541140019893646
# 120
# 0 This is a really dumb ->  movie... The haircut for the redeeming lunatics is pretty good with such likable actors as Maggie Bights(She deserves to be featured, as an actress 1.3785136938095093
# 125
# 0 MARS is probably the ->  only actor I could not save by leave my memories off. It was so bad that I could not finish this movie. I went to restart at a local show 2.388733148574829
# 130
# 1 About 10 minutes in to ->  the movie playing, I have to say that it barely haunts this movie, just to get to the excellent dialog.. The opening scene is supreme and still atmospheric 0.840847909450531
# 135
# 0 Kweer kl -> ondz is the best musical of the year. I use most other peoples favourite, joskain, burgard. Klondberg is also an -1.407822847366333
# 140
# 0 I realize that living in ->  Athens, GA, always makes for some excellent entertainment. But no expensive rental here? No, what made those people pay all the wayn their local council to 0.26040083169937134
# 145
# 1 This espionage melodrama -> , directed by Kris Litton is a unique tale about a man trying to fall in love with girl (Jane Eyre), succeeded by king (Tom Franks) 1.230529546737671
# 150
# 0 This movie is currently remembered ->  as one of the goofs that I've ever seen in a movie.<br /><br />Yes, it comes with all sorts of nasty effects, visual 0.45701566338539124
# 155
# 0 This starts almost like an ->  old car and crashes away in Northumberland start of showing how they are claimed lads. put me in one of these to refer to these are just resp 0.1560552716255188
# 160
# 0 Major disappointment! Not to ->  say bad either. <br /><br />Someone reminded me of the Fascist movies that I watched all the way through. Yes, the state follows the 0.8707109689712524
# 165
# 0 It's just as well ->  em slow as the last one. The whole plot is about how our world is dying in a major way. They must just don't let it. An abandoned 0.3375195562839508
# 170
# 1 A failure. The movie ->  I always wanted to see was whole because of the Supernatural and I felt it was BLURs...Could be the first choice but is anything and first, -2.0572774410247803
# 175
# 1 Hey i had a he -> ntai flashback with my 200 so to be honest this movie was so great old movies with incredible effects. it helped our movie, which is a ninja movie that 1.6395206451416016
# 180
# 1 What this movie fails from ->  it is a very boring it's worth the $17 What this film fails is the story it fails i had to listen to the movie like a decent teen, -1.995874285697937
# 185
# 1 Roy Rogers stars as Jesse ->  in this fun road movie from the story opens of his experiences as a teenager. He's always been fun and quirky, while this is working out a lot of 2.0989270210266113
# 190
# 0 David Lynch is a remarkable ->  individual; the best of the worst movies iHub single iceblades King of Horror ) The cheapest horror crap i was expecting at the worst Movie was totally water 1.1718684434890747
# 195
# 1 This is a coming- -> of-age film that is so funny. Nothing says what you think of the movie in the movie, I say so I am not proud of it. It 2.2048909664154053
