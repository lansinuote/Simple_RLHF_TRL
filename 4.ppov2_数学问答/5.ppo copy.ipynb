# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %run 1.tokenizer.ipynb

tokenizer

# %%
# %run 2.dataset.ipynb


def f(data):
    data = [i['text'] for i in data]
    return tokenizer(data,
                     padding=True,
                     truncation=True,
                     max_length=32,
                     device=device,
                     add_bos_token=True,
                     add_eos_token=False,
                     padding_side='left')['input_ids']


loader = get_loader(f, negative_label=False, with_answer=False)

len(loader), next(iter(loader))
# Out:
# (125000,
#  tensor([[ 0, 11,  9,  7, 10, 13,  9,  8,  7,  5, 17],
#          [ 0, 10,  3, 11,  5, 15,  9,  6,  4,  6, 17],
#          [ 2,  2,  0, 11, 12, 14,  4,  7, 12, 10, 17],
#          [ 0, 10,  3,  7,  7, 14, 10,  9, 11,  5, 17],
#          [ 0,  6, 11, 12,  5, 16,  5,  4, 12, 11, 17],
#          [ 0,  5,  7, 12,  9, 13,  8, 11,  8,  5, 17],
#          [ 0, 12,  7,  6,  5, 13, 11,  7,  5,  6, 17],
#          [ 2,  0, 10,  5,  8, 11, 16,  5,  7, 12, 17],
#          [ 2,  0, 10,  3,  6, 14,  9,  3,  9,  6, 17],
#          [ 0,  7,  3,  8,  7, 15,  6,  7, 12,  4, 17],
#          [ 0,  8,  8,  5,  3, 14,  9,  8,  5,  4, 17],
#          [ 0,  7, 12,  5, 10, 14,  8,  6,  6,  5, 17],
#          [ 0,  4, 11,  4,  4, 16,  5,  7, 10, 12, 17],
#          [ 0,  6,  4, 10,  6, 15, 10,  9,  7,  9, 17],
#          [ 0,  8,  7,  7, 11, 13,  7, 10,  3, 12, 17],
#          [ 0,  5, 11, 10, 10, 16,  7,  9, 12,  8, 17]], device='cuda:0'))

# %%
from transformers import AutoModelForCausalLM, AutoModelForSequenceClassification
from trl.trainer.utils import disable_dropout_in_model

model_actor = AutoModelForCausalLM.from_pretrained('model/ppo').to(device)
model_actor_ref = AutoModelForCausalLM.from_pretrained('model/actor').to(
    device)

model_critic = AutoModelForSequenceClassification.from_pretrained(
    'model/critic', num_labels=1).to(device)
model_critic_ref = AutoModelForSequenceClassification.from_pretrained(
    'model/critic', num_labels=1).to(device)

model_actor.generation_config.eos_token_id = None
model_actor.generation_config.pad_token_id = None

for i in [model_actor, model_actor_ref, model_critic, model_critic_ref]:
    disable_dropout_in_model(i)

optimizer = torch.optim.AdamW(list(model_actor.parameters()) +
                              list(model_critic.parameters()),
                              lr=5e-6)
# Out:
# The `GPTNeoXSdpaAttention` class is deprecated in favor of simply modifying the `config._attn_implementation`attribute of the `GPTNeoXAttention` class! It will be removed in v4.48

# %%
def get_value(critic, question, answer, shift=True):
    input_ids = torch.cat((question, answer), 1)
    attention_mask = input_ids != tokenizer.pad_token_id
    position_ids = attention_mask.cumsum(1) - attention_mask.long()
    input_ids = torch.masked_fill(input_ids, ~attention_mask, 0)

    #[b, lens, 768]
    last_hidden_state = critic.gpt_neox(
        input_ids=input_ids,
        attention_mask=attention_mask,
        position_ids=position_ids).last_hidden_state

    #[b, lens]
    value = critic.score(last_hidden_state)

    if shift:
        value = value[:, question.shape[1] - 1:-1].squeeze(-1)

    return value


get_value(model_critic,
          torch.randint(0, 10, [2, 5]).to(device),
          torch.randint(0, 10, [2, 15]).to(device)).shape
# Out:
# torch.Size([2, 15])

# %%
def get_logprob(actor, question, answer):
    input_ids = torch.cat((question, answer), 1)
    attention_mask = input_ids != tokenizer.pad_token_id
    position_ids = attention_mask.cumsum(1) - attention_mask.long()
    input_ids = torch.masked_fill(input_ids, ~attention_mask, 0)

    logits = actor(input_ids=input_ids,
                   attention_mask=attention_mask,
                   position_ids=position_ids).logits

    logits = logits[:, question.shape[1] - 1:-1]
    logits /= 0.7

    logprob = logits.log_softmax(dim=-1)
    logprob = logprob.gather(2, answer.unsqueeze(-1)).squeeze(-1)

    return logprob


get_logprob(model_actor,
            torch.randint(0, 10, [2, 5]).to(device),
            torch.randint(0, 10, [2, 15]).to(device)).shape
# Out:
# torch.Size([2, 15])

# %%
def get_advantage(value, reward_kl):
    advantage = []
    last = 0
    for i in reversed(range(value.shape[1])):
        value_next = 0.0
        if i < value.shape[1] - 1:
            value_next = value[:, i + 1]

        delta = reward_kl[:, i] + value_next - value[:, i]

        last = delta + 0.95 * last

        advantage.append(last)

    return torch.stack(advantage[::-1], axis=1)


get_advantage(torch.randn(4, 25), torch.randn(4, 25)).shape
# Out:
# torch.Size([4, 25])

# %%
from trl.trainer.utils import first_true_indices


@torch.no_grad()
def get_data(question):
    #====answer====
    answer = model_actor.generate(
        input_ids=question,
        attention_mask=(question != tokenizer.pad_token_id).long(),
        min_length=-1,
        max_length=50,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=tokenizer.eos_token_id,
        top_k=0.0,
        top_p=1.0,
        do_sample=True)

    answer = answer[:, question.shape[1]:]

    #求结束位置
    ends = first_true_indices(answer == tokenizer.pad_token_id).tolist()

    #====prob,value====
    prob_old = get_logprob(model_actor, question, answer)
    prob_ref = get_logprob(model_actor_ref, question, answer)
    value_old = get_value(model_critic, question, answer)
    #这里因为有可能取到最后一个字,所以不能偏移,如果偏移的话,最后一个字的值会被裁剪掉.
    value_ref = get_value(model_critic_ref, question, answer, shift=False)

    #end以后的值value归零
    for i, end in enumerate(ends):
        prob_old[i, end:] = 1.0
        prob_ref[i, end:] = 1.0
        value_old[i, end + 1:] = 0.0

    #====reward====
    reward = []
    for i, end in enumerate(ends):
        #没有eos符号的,置为-1
        if tokenizer.eos_token_id not in answer[i]:
            #reward.append(-1)
            #continue
            pass
        #取最后一个字的value作为reward
        reward.append(value_ref[i, end + question.shape[1] - 1])
    reward = torch.FloatTensor(reward).to(device)

    #====advantage====
    #计算kl散度
    reward_kl = -0.05 * (prob_old - prob_ref)

    #把reward加在最后一个字的kl散度上
    for i, end in enumerate(ends):
        if end == len(answer[i]):
            end = -1
        #assert end == -1

        reward_kl[i, end] += reward[i]

    advantage = get_advantage(value_old, reward_kl)
    returns = advantage + value_old

    #标准化,保持数值稳定
    select = torch.cat([adv[:end] for adv, end in zip(advantage, ends)])
    advantage = (advantage - select.mean()) / (select.var() + 1e-8)**0.5

    #end以后的值归零
    for i, end in enumerate(ends):
        advantage[i, end:] = 0

    return question, answer, ends, prob_old, value_old, advantage, returns


get_data(next(iter(loader)))
# Out:
# (tensor([[ 0,  5,  3,  4,  7, 15,  7, 11,  9,  7, 17],
#          [ 0,  9, 11, 12,  7, 13,  7,  4, 12,  5, 17],
#          [ 0, 12, 11,  6, 10, 16, 12,  7,  5,  3, 17],
#          [ 0,  6,  6,  9,  7, 13, 12, 11,  6,  3, 17],
#          [ 0,  8,  8,  4, 10, 15,  9,  8,  7,  8, 17],
#          [ 0,  9,  4, 11,  5, 15, 11,  7, 10,  6, 17],
#          [ 0,  4,  6,  8,  3, 14,  6,  7,  3,  8, 17],
#          [ 0,  7,  6,  5,  6, 15,  6,  7,  3,  8, 17],
#          [ 0,  6, 10,  6,  9, 13,  7, 10, 11,  3, 17],
#          [ 2,  0,  7,  8,  8,  7, 15,  8, 10,  6, 17],
#          [ 2,  0,  6,  6,  3,  4, 14,  8, 10,  3, 17],
#          [ 0,  6,  8, 11,  6, 16, 10,  7,  4,  5, 17],
#          [ 2,  0,  9, 11,  8, 12, 14,  5, 11, 10, 17],
#          [ 0, 12, 11,  4,  7, 15,  6, 12, 10, 12, 17],
#          [ 0,  4,  9,  8,  3, 14, 10,  3,  5, 12, 17],
#          [ 0,  5, 10, 12,  4, 16, 10, 11,  4,  5, 17]], device='cuda:0'),
#  tensor([[12, 12,  9,  4, 11,  6,  9,  1,  2],
#          [ 4,  3,  3, 11,  9,  1,  2,  2,  2],
#          [ 4,  1,  2,  2,  2,  2,  2,  2,  2],
#          [ 4,  6,  4, 12,  7,  1,  2,  2,  2],
#          [ 6,  9, 12, 10,  8,  6,  9,  8,  1],
#          [ 8,  5,  5, 10,  7,  7,  9,  9,  1],
#          [14,  4,  3,  8,  8,  1,  2,  2,  2],
#          [ 4,  7,  3,  5,  6,  9,  4,  8,  1],
#          [10,  8,  4,  9,  1,  2,  2,  2,  2],
#          [ 5,  8,  8, 12,  5,  9,  5,  1,  2],
#          [ 5,  9,  6,  4,  1,  2,  2,  2,  2],
#          [ 3,  1,  2,  2,  2,  2,  2,  2,  2],
#          [ 9,  8, 10,  5,  1,  2,  2,  2,  2],
#          [ 6, 11, 10,  4,  7, 12,  7,  9,  1],
#          [14,  8,  6, 10, 12,  1,  2,  2,  2],
#          [ 3,  1,  2,  2,  2,  2,  2,  2,  2]], device='cuda:0'),
#  [8, 6, 2, 6, 9, 9, 6, 9, 5, 8, 5, 2, 5, 9, 6, 2],
#  tensor([[-7.7975e-03, -1.2888e+00, -2.4014e+00, -2.4783e+00, -2.3742e+00,
#           -1.1300e+00, -9.6559e-06,  0.0000e+00,  1.0000e+00],
#          [ 0.0000e+00, -2.6788e-02, -1.4305e-06, -5.7220e-06, -1.9832e-02,
#            0.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-4.7684e-06,  0.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00,
#            1.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-4.7684e-07, -1.0335e-04, -1.3113e-06, -1.1086e-05, -4.7684e-07,
#            0.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-2.7895e-05, -3.9257e-02, -2.4857e+00, -2.1692e+00, -2.1501e+00,
#           -2.3848e+00, -4.7970e-04, -1.3471e-05,  0.0000e+00],
#          [-9.3917e-04, -4.7755e-01, -2.2289e+00, -2.2853e+00, -2.4162e+00,
#           -2.4200e+00, -1.7655e+00, -1.1253e-04,  0.0000e+00],
#          [-3.9339e-06, -3.4571e-06, -9.5367e-07, -1.8120e-05, -5.9605e-07,
#            0.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-1.3113e-06, -1.2391e-02, -4.5777e-01, -2.5130e+00, -2.2721e+00,
#           -2.3804e+00, -5.2686e-03, -9.2983e-06,  0.0000e+00],
#          [-2.4143e+00, -9.5367e-07, -2.1458e-06, -5.2452e-06,  0.0000e+00,
#            1.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-1.1921e-07, -3.6280e-01, -1.7791e+00, -1.9973e+00, -2.4018e+00,
#           -1.9305e+00, -5.7100e-05,  0.0000e+00,  1.0000e+00],
#          [-1.4305e-06, -3.6134e-02, -2.1100e-05, -6.9916e-04,  0.0000e+00,
#            1.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-3.5763e-07,  0.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00,
#            1.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-1.0585e-04, -3.2657e-01, -3.4148e-04, -3.4212e-05,  0.0000e+00,
#            1.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-1.2182e-04, -2.5008e-02, -1.7442e+00, -2.6788e+00, -2.4791e+00,
#           -1.9437e+00, -1.8558e+00, -1.6689e-06,  0.0000e+00],
#          [-1.7881e-06, -2.0073e-04, -1.2796e-03, -5.0068e-06, -1.3113e-06,
#            0.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00],
#          [-1.3113e-06,  0.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00,
#            1.0000e+00,  1.0000e+00,  1.0000e+00,  1.0000e+00]], device='cuda:0'),
#  tensor([[ 4.5865e-01,  5.0965e-01,  9.0185e-02,  6.7766e-02,  1.7069e-01,
#            1.9212e-01,  2.5038e-01,  3.0541e-01,  9.6079e-01],
#          [ 3.9914e-01,  1.3618e-01,  2.1245e-01,  1.1784e-02, -4.1269e-02,
#           -1.1420e-02,  3.6333e-01,  0.0000e+00,  0.0000e+00],
#          [ 5.6112e-01,  3.7436e-01,  9.7506e-01,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 3.9084e-01,  5.8755e-02,  1.5738e-01,  1.1225e-01,  5.5460e-02,
#            5.9475e-02,  9.2204e-01,  0.0000e+00,  0.0000e+00],
#          [ 3.0294e-01,  1.2045e-01,  1.7690e-01,  1.6692e-01,  2.5948e-01,
#            2.9674e-01,  1.2663e-01,  1.3545e-01,  1.7787e-01],
#          [ 2.6745e-01,  3.5798e-01,  2.1083e-01,  6.9445e-02,  5.6890e-02,
#            7.9665e-02,  2.8065e-01,  3.3813e-01,  5.0595e-01],
#          [ 6.2364e-01,  8.2835e-02,  5.0184e-01,  1.6146e-01, -1.5688e-02,
#           -3.3399e-02, -6.6372e-03,  0.0000e+00,  0.0000e+00],
#          [ 3.9871e-01,  7.7757e-02,  1.5484e-01,  4.5246e-01,  2.6515e-01,
#            2.7281e-01,  6.4453e-03,  2.3020e-01,  1.5878e-01],
#          [ 6.5689e-01, -3.8798e-01,  6.0746e-02,  1.3610e-04, -1.1787e-02,
#            9.8938e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 4.9973e-01,  1.2536e-01,  3.4096e-01,  2.3863e-01,  3.9398e-01,
#            2.7653e-01,  3.3221e-01,  5.1196e-01,  9.8449e-01],
#          [ 5.1761e-01,  2.4401e-01,  1.6249e-02,  1.7425e-02,  7.1913e-02,
#            8.3639e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 7.2559e-01,  1.1874e-01,  9.8722e-01,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 3.6586e-01,  7.7371e-02,  3.8570e-02, -7.9035e-03,  1.1590e-01,
#            9.4661e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 1.1669e-01,  1.6276e-01,  3.0259e-01,  5.0925e-01,  3.5416e-01,
#            3.7204e-01,  1.9404e-01,  9.7575e-02,  2.7752e-01],
#          [ 2.9089e-01,  9.0882e-02,  1.7834e-01,  6.0361e-01, -9.1017e-03,
#            1.8429e-02,  8.2652e-01,  0.0000e+00,  0.0000e+00],
#          [ 7.9415e-01,  1.0798e-01,  9.8991e-01,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]], device='cuda:0'),
#  tensor([[-0.4562, -0.5355,  0.5040,  0.6393,  0.4536,  0.4942,  0.5735,  0.5208,
#            0.0000],
#          [-3.1201, -2.5741, -0.7999, -0.2871, -0.1155, -0.1442,  0.0000,  0.0000,
#            0.0000],
#          [-0.1225,  0.3912,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [-0.2197,  0.6514,  0.4940,  0.6869,  0.9190,  1.0117,  0.0000,  0.0000,
#            0.0000],
#          [-0.1228,  0.3802,  0.3120,  0.4839,  0.3308,  0.3198,  0.8070,  0.8827,
#            0.8777],
#          [ 0.1194, -0.0369,  0.3355,  0.7541,  0.8827,  0.9128,  0.5062,  0.4194,
#            0.0772],
#          [-3.8659, -2.6661, -2.2211, -1.4346, -1.0139, -0.9688,  0.0000,  0.0000,
#            0.0000],
#          [-1.0081, -0.2063, -0.3513, -0.3316,  0.1835,  0.2309,  0.9418,  0.4911,
#            0.7494],
#          [-4.0085, -0.0868, -1.1563, -1.0117, -0.9808,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [-0.5162,  0.4448,  0.1144,  0.4581,  0.1646,  0.5253,  0.4574,  0.0875,
#            0.0000],
#          [-0.9052, -0.2160,  0.7281,  0.8178,  0.7793,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [-0.5152,  1.0257,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [-0.0564,  0.7145,  0.9126,  1.1308,  0.9362,  0.0000,  0.0000,  0.0000,
#            0.0000],
#          [ 0.2245,  0.1981,  0.0827, -0.3427,  0.0549,  0.0545,  0.5686,  0.9371,
#            0.5919],
#          [-0.1096,  0.4378,  0.2970, -0.6940,  0.8521,  0.8826,  0.0000,  0.0000,
#            0.0000],
#          [-0.6728,  1.0576,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#            0.0000]], device='cuda:0'),
#  tensor([[ 7.0173e-01,  7.1928e-01,  7.3849e-01,  7.7317e-01,  7.9772e-01,
#            8.3629e-01,  9.2802e-01,  9.6079e-01,  9.6079e-01],
#          [-4.8198e-01, -5.1452e-01,  3.1051e-01,  3.2624e-01,  3.4558e-01,
#            3.6333e-01,  3.6333e-01,  0.0000e+00,  0.0000e+00],
#          [ 9.4503e-01,  9.7506e-01,  9.7506e-01,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 7.3373e-01,  7.6926e-01,  8.0146e-01,  8.3774e-01,  8.7891e-01,
#            9.2204e-01,  9.2204e-01,  0.0000e+00,  0.0000e+00],
#          [ 6.8671e-01,  7.1652e-01,  7.4416e-01,  8.0676e-01,  8.3467e-01,
#            8.6729e-01,  9.0279e-01,  9.4358e-01,  9.8388e-01],
#          [ 7.5344e-01,  7.7801e-01,  7.8804e-01,  8.2329e-01,  8.6501e-01,
#            9.0050e-01,  9.2989e-01,  9.5074e-01,  9.7414e-01],
#          [-5.7222e-01, -6.0670e-01,  1.3000e-04, -8.3608e-03, -7.9753e-03,
#           -6.6372e-03, -6.6372e-03,  0.0000e+00,  0.0000e+00],
#          [ 4.0888e-01,  4.2630e-01,  4.4219e-01,  7.4813e-01,  7.7819e-01,
#            8.0586e-01,  8.3951e-01,  8.7305e-01,  9.1065e-01],
#          [-5.9914e-01,  1.0995e-02,  8.3763e-03,  8.8100e-03,  9.8938e-03,
#            9.8938e-03,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 7.1751e-01,  7.4868e-01,  8.2486e-01,  8.6757e-01,  8.9903e-01,
#            9.3382e-01,  9.6085e-01,  9.8449e-01,  9.8449e-01],
#          [ 5.7122e-01,  5.8845e-01,  7.5911e-01,  7.9815e-01,  8.3639e-01,
#            8.3639e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 9.4379e-01,  9.8722e-01,  9.8722e-01,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 7.7765e-01,  8.1451e-01,  8.5929e-01,  9.0493e-01,  9.4661e-01,
#            9.4661e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00],
#          [ 6.4703e-01,  6.8195e-01,  7.7309e-01,  8.0023e-01,  8.1292e-01,
#            8.3064e-01,  8.6962e-01,  9.2866e-01,  9.6294e-01],
#          [ 6.8022e-01,  7.1124e-01,  7.3928e-01,  7.4635e-01,  7.8611e-01,
#            8.2652e-01,  8.2652e-01,  0.0000e+00,  0.0000e+00],
#          [ 9.4581e-01,  9.8991e-01,  9.8991e-01,  0.0000e+00,  0.0000e+00,
#            0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00]], device='cuda:0'))

# %%
def train(question, answer, ends, prob_old, value_old, advantage, returns):
    for _ in range(4):
        #重新计算value和prob
        prob_new = get_logprob(model_actor, question, answer)
        value_new = get_value(model_critic, question, answer)

        #end以后的值value归零
        for i, end in enumerate(ends):
            prob_new[i, end:] = 1.0
            value_new[i, end + 1:] = 0

        #计算critic部分的loss
        value_clip = torch.clamp(value_new, value_old - 0.2, value_old + 0.2)
        loss_vf1 = (value_new - returns)**2
        loss_vf2 = (value_clip - returns)**2
        loss_vf = torch.max(loss_vf1, loss_vf2)

        #计算actor部分的loss
        ratio = (prob_new - prob_old).exp()
        loss_pg1 = -advantage * ratio
        loss_pg2 = -advantage * torch.clamp(ratio, 0.8, 1.2)
        loss_pg = torch.max(loss_pg1, loss_pg2)

        #丢弃end之后的部分
        loss_vf = [xi[:end + 1] for xi, end in zip(loss_vf, ends)]
        loss_pg = [xi[:end + 1] for xi, end in zip(loss_pg, ends)]
        loss_vf = torch.cat(loss_vf).mean()
        loss_pg = torch.cat(loss_pg).mean()

        loss = loss_pg + 0.05 * loss_vf
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()


train(*get_data(next(iter(loader))))

# %%
for i in range(1_0000_0000):
    train(*get_data(next(iter(loader))))

    if i % 200 == 0:
        print(i)
        input_ids = next(iter(loader))[0:1]

        gen = model_actor.generate(input_ids=input_ids,
                                   min_length=-1,
                                   max_length=50,
                                   pad_token_id=tokenizer.pad_token_id,
                                   eos_token_id=tokenizer.eos_token_id,
                                   top_k=0.0,
                                   top_p=1.0,
                                   do_sample=True)

        question = tokenizer.decode(input_ids[0])

        answer = question
        answer = answer[answer.index(tokenizer.bos_token) + 1:]
        answer = answer[:answer.index('=')]
        answer = int(eval(answer))
        gen = tokenizer.decode(gen[0, input_ids.shape[1]:])

        print({'question': question, 'answer': answer, 'gen': gen})

    if (i + 1) % 2000 == 0:
        model_actor.save_pretrained('model/ppo_copy_%d' % i)

model_actor.save_pretrained('model/ppo_copy')
# Out:
# 0
# {'question': 'B3393+1360=', 'answer': 4753, 'gen': '4753E'}
# 200
# {'question': 'B4380-4033=', 'answer': 347, 'gen': '347E'}
# 400
# {'question': 'B7429-1701=', 'answer': 5728, 'gen': '5728E'}
# 600
# {'question': 'B6549/853=', 'answer': 7, 'gen': '7E'}
# 800
# {'question': 'B2196-5373=', 'answer': -3177, 'gen': '-3177E'}
# 1000
# {'question': 'B9824*6189=', 'answer': 60800736, 'gen': '59860376E'}
# 1200
# {'question': 'B2742+3678=', 'answer': 6420, 'gen': '6420E'}
# 1400
# {'question': 'B3055*8870=', 'answer': 27097850, 'gen': '26817850E'}
# 1600
# {'question': 'B6325*932=', 'answer': 5894900, 'gen': '5907200E'}
# 1800
# {'question': 'B3414/5155=', 'answer': 0, 'gen': '0E'}
# 2000
# {'question': 'B3655/6885=', 'answer': 0, 'gen': '0E'}
# 2200
# {'question': 'B9518/9036=', 'answer': 1, 'gen': '1E'}
# 2400
# {'question': 'B92*3833=', 'answer': 352636, 'gen': '355196E'}
# 2600
# {'question': 'B9242*7937=', 'answer': 73353754, 'gen': '74113734E'}
# 2800
# {'question': 'B4557/2072=', 'answer': 2, 'gen': '2E'}
# 3000
# {'question': 'B5571/4104=', 'answer': 1, 'gen': '1E'}
# 3200
# {'question': 'B39+9031=', 'answer': 9070, 'gen': '9070E'}
# 3400
# {'question': 'B9168*2900=', 'answer': 26587200, 'gen': '26487200E'}
# 3600
# {'question': 'B1913+8565=', 'answer': 10478, 'gen': '10478E'}
# 3800
# {'question': 'B8188/2347=', 'answer': 3, 'gen': '3E'}
# 4000
# {'question': 'B4274/4932=', 'answer': 0, 'gen': '0E'}
# 4200
# {'question': 'B1260-3540=', 'answer': -2280, 'gen': '-2290E'}
# 4400
# {'question': 'B6765*2714=', 'answer': 18360210, 'gen': '18882710E'}
# 4600
# {'question': 'B7285-302=', 'answer': 6983, 'gen': '6983E'}
# 4800
# {'question': 'B7006*6412=', 'answer': 44922472, 'gen': '44681592E'}
# 5000
# {'question': 'B1895/8705=', 'answer': 0, 'gen': '0E'}
# 5200
# {'question': 'B5474+305=', 'answer': 5779, 'gen': '5779E'}
# 5400
# {'question': 'B2454*7906=', 'answer': 19401324, 'gen': '18722824E'}
# 5600
# {'question': 'B7443*444=', 'answer': 3304692, 'gen': '3306932E'}
# 5800
# {'question': 'B7354-5207=', 'answer': 2147, 'gen': '2147E'}
# 6000
# {'question': 'B8722*7921=', 'answer': 69086962, 'gen': '68083242E'}
# 6200
# {'question': 'B4259*6476=', 'answer': 27581284, 'gen': '27805284E'}
# 6400
# {'question': 'B2699+2550=', 'answer': 5249, 'gen': '5249E'}
# 6600
# {'question': 'B5249+5796=', 'answer': 11045, 'gen': '11045E'}
# 6800
# {'question': 'B5012/7273=', 'answer': 0, 'gen': '0E'}
# 7000
# {'question': 'B4971*9482=', 'answer': 47135022, 'gen': '47709702E'}
# 7200
# {'question': 'B5763+441=', 'answer': 6204, 'gen': '6104E'}
# 7400
# {'question': 'B4545+6911=', 'answer': 11456, 'gen': '11456E'}
# 7600
# {'question': 'B3505/974=', 'answer': 3, 'gen': '3E'}
# 7800
# {'question': 'B4046-2748=', 'answer': 1298, 'gen': '1298E'}
# 8000
# {'question': 'B5988-5032=', 'answer': 956, 'gen': '956E'}
# 8200
# {'question': 'B4689-7450=', 'answer': -2761, 'gen': '-2761E'}
# 8400
# {'question': 'B7490/8395=', 'answer': 0, 'gen': '0E'}
# 8600
# {'question': 'B5198*8634=', 'answer': 44879532, 'gen': '44801812E'}
# 8800
# {'question': 'B5752+3287=', 'answer': 9039, 'gen': '9039E'}
# 9000
# {'question': 'B999+8009=', 'answer': 9008, 'gen': '8008E'}
# 9200
# {'question': 'B9978+615=', 'answer': 10593, 'gen': '10633E'}
# 9400
# {'question': 'B1297/4887=', 'answer': 0, 'gen': '0E'}
# 9600
# {'question': 'B4373*2797=', 'answer': 12231281, 'gen': '12595821E'}
# 9800
# {'question': 'B4494*1147=', 'answer': 5154618, 'gen': '5377658E'}
# 10000
# {'question': 'B1056-4621=', 'answer': -3565, 'gen': '-3565E'}
# 10200
# {'question': 'B6578+2712=', 'answer': 9290, 'gen': '9290E'}
# 10400
# {'question': 'B2097-8951=', 'answer': -6854, 'gen': '-6854E'}
# 10600
# {'question': 'B2709+6535=', 'answer': 9244, 'gen': '9244E'}
# 10800
# {'question': 'B2411*2544=', 'answer': 6133584, 'gen': '6724084E'}
# 11000
# {'question': 'B9853*9991=', 'answer': 98441323, 'gen': '98602183E'}
# 11200
# {'question': 'B6296*4473=', 'answer': 28162008, 'gen': '28226348E'}
# 11400
# {'question': 'B7919-1814=', 'answer': 6105, 'gen': '6105E'}
# 11600
# {'question': 'B9619*5024=', 'answer': 48325856, 'gen': '48490156E'}
# 11800
# {'question': 'B6143+7155=', 'answer': 13298, 'gen': '13298E'}
# 12000
# {'question': 'B6388/732=', 'answer': 8, 'gen': '8E'}
# 12200
# {'question': 'B8335+6737=', 'answer': 15072, 'gen': '15072E'}
# 12400
# {'question': 'B4657*161=', 'answer': 749777, 'gen': '758177E'}
# 12600
# {'question': 'B6446/118=', 'answer': 54, 'gen': '56E'}
# 12800
# {'question': 'B4331*8854=', 'answer': 38346674, 'gen': '38424334E'}
# 13000
# {'question': 'B1735+4488=', 'answer': 6223, 'gen': '6223E'}
# 13200
# {'question': 'B3991-3198=', 'answer': 793, 'gen': '793E'}
# 13400
# {'question': 'B2903*6708=', 'answer': 19473324, 'gen': '20262104E'}
# 13600
# {'question': 'B4068+1252=', 'answer': 5320, 'gen': '5320E'}
# 13800
# {'question': 'B1930*6357=', 'answer': 12269010, 'gen': '12595610E'}
# 14000
# {'question': 'B972+6590=', 'answer': 7562, 'gen': '7562E'}
# 14200
# {'question': 'B4177-4834=', 'answer': -657, 'gen': '-557E'}
# 14400
# {'question': 'B1406-7871=', 'answer': -6465, 'gen': '-6465E'}
# 14600
# {'question': 'B1563-5026=', 'answer': -3463, 'gen': '-3463E'}
# 14800
# {'question': 'B3296-2496=', 'answer': 800, 'gen': '800E'}
# 15000
# {'question': 'B1120/2307=', 'answer': 0, 'gen': '0E'}
# 15200
# {'question': 'B1285/5101=', 'answer': 0, 'gen': '0E'}
# 15400
# {'question': 'B4910*4697=', 'answer': 23062270, 'gen': '22891270E'}
# 15600
# {'question': 'B3036-7328=', 'answer': -4292, 'gen': '-4292E'}
# 15800
# {'question': 'B4393/863=', 'answer': 5, 'gen': '5E'}
# 16000
# {'question': 'B5288+9552=', 'answer': 14840, 'gen': '14840E'}
# 16200
# {'question': 'B8142/7818=', 'answer': 1, 'gen': '1E'}
# 16400
# {'question': 'B7544-9970=', 'answer': -2426, 'gen': '-2426E'}
# 16600
# {'question': 'B5082+4232=', 'answer': 9314, 'gen': '9314E'}
# 16800
# {'question': 'B2012*7423=', 'answer': 14935076, 'gen': '15272996E'}
# 17000
# {'question': 'B8787*3889=', 'answer': 34172643, 'gen': '34998243E'}
# 17200
# {'question': 'B8564*708=', 'answer': 6063312, 'gen': '6077852E'}
# 17400
# {'question': 'B1511/8832=', 'answer': 0, 'gen': '0E'}
# 17600
# {'question': 'B7525+1595=', 'answer': 9120, 'gen': '9120E'}
# 17800
# {'question': 'B5956+3381=', 'answer': 9337, 'gen': '9337E'}
# 18000
# {'question': 'B2008-9160=', 'answer': -7152, 'gen': '-7152E'}
# 18200
# {'question': 'B9039-9570=', 'answer': -531, 'gen': '-531E'}
# 18400
# {'question': 'B6463-1973=', 'answer': 4490, 'gen': '4490E'}
# 18600
# {'question': 'B8892/6075=', 'answer': 1, 'gen': '1E'}
# 18800
# {'question': 'B3175+9511=', 'answer': 12686, 'gen': '12686E'}
# 19000
# {'question': 'B1038-1956=', 'answer': -918, 'gen': '-918E'}
# 19200
# {'question': 'B1844/1337=', 'answer': 1, 'gen': '1E'}
# 19400
# {'question': 'B3809-2699=', 'answer': 1110, 'gen': '1110E'}
# 19600
# {'question': 'B6356*8651=', 'answer': 54985756, 'gen': '54220456E'}
# 19800
# {'question': 'B204+7713=', 'answer': 7917, 'gen': '7917E'}
# 20000
# {'question': 'B4005*7608=', 'answer': 30470040, 'gen': '30585940E'}
# 20200
# {'question': 'B8430+8045=', 'answer': 16475, 'gen': '16475E'}
# 20400
# {'question': 'B7781+9254=', 'answer': 17035, 'gen': '17035E'}
# 20600
# {'question': 'B3213*8374=', 'answer': 26905662, 'gen': '27026822E'}
# 20800
# {'question': 'B8107+3290=', 'answer': 11397, 'gen': '12397E'}
# 21000
# {'question': 'B5737/3380=', 'answer': 1, 'gen': '1E'}
# 21200
# {'question': 'B4182*2995=', 'answer': 12525090, 'gen': '12444090E'}
# 21400
# {'question': 'B4135-3545=', 'answer': 590, 'gen': '590E'}
# 21600
# {'question': 'B864/5450=', 'answer': 0, 'gen': '0E'}
# 21800
# {'question': 'B8240-4696=', 'answer': 3544, 'gen': '3544E'}
# 22000
# {'question': 'B3842/5894=', 'answer': 0, 'gen': '0E'}
# 22200
# {'question': 'B5993+5383=', 'answer': 11376, 'gen': '11376E'}
# 22400
# {'question': 'B629/5035=', 'answer': 0, 'gen': '0E'}
# 22600
# {'question': 'B9127/3004=', 'answer': 3, 'gen': '3E'}
# 22800
# {'question': 'B2134/5281=', 'answer': 0, 'gen': '0E'}
# 23000
# {'question': 'B6152+5788=', 'answer': 11940, 'gen': '11940E'}
# 23200
# {'question': 'B327+4756=', 'answer': 5083, 'gen': '5083E'}
# 23400
# {'question': 'B6306/6638=', 'answer': 0, 'gen': '0E'}
# 23600
# {'question': 'B446+6107=', 'answer': 6553, 'gen': '6553E'}
# 23800
# {'question': 'B1114+7795=', 'answer': 8909, 'gen': '8909E'}
# 24000
# {'question': 'B3679-6155=', 'answer': -2476, 'gen': '-2476E'}
# 24200
# {'question': 'B1572-6685=', 'answer': -5113, 'gen': '-5113E'}
# 24400
# {'question': 'B2397+8996=', 'answer': 11393, 'gen': '11393E'}
# 24600
# {'question': 'B7321*2654=', 'answer': 19429934, 'gen': '19460734E'}
# 24800
# {'question': 'B1498+1430=', 'answer': 2928, 'gen': '2928E'}
# 25000
# {'question': 'B4654+3008=', 'answer': 7662, 'gen': '7662E'}
# 25200
# {'question': 'B4076-6462=', 'answer': -2386, 'gen': '-2386E'}
# 25400
# {'question': 'B6910*3240=', 'answer': 22388400, 'gen': '22742400E'}
# 25600
# {'question': 'B1971+7557=', 'answer': 9528, 'gen': '9528E'}
# 25800
# {'question': 'B433+2112=', 'answer': 2545, 'gen': '2545E'}
# 26000
# {'question': 'B9413*7778=', 'answer': 73214314, 'gen': '73313114E'}
# 26200
# {'question': 'B5337/1134=', 'answer': 4, 'gen': '4E'}
# 26400
# {'question': 'B1423+2736=', 'answer': 4159, 'gen': '4159E'}
# 26600
# {'question': 'B9478+6951=', 'answer': 16429, 'gen': '16429E'}
# 26800
# {'question': 'B9336/7929=', 'answer': 1, 'gen': '1E'}
# 27000
# {'question': 'B5111-314=', 'answer': 4797, 'gen': '4807E'}
# 27200
# {'question': 'B778-2361=', 'answer': -1583, 'gen': '-1583E'}
# 27400
# {'question': 'B3729+2851=', 'answer': 6580, 'gen': '6580E'}
# 27600
# {'question': 'B2929-6640=', 'answer': -3711, 'gen': '-3711E'}
# 27800
# {'question': 'B9136/4165=', 'answer': 2, 'gen': '2E'}
# 28000
# {'question': 'B6431+4034=', 'answer': 10465, 'gen': '10465E'}
# 28200
# {'question': 'B1668/1869=', 'answer': 0, 'gen': '0E'}
# 28400
# {'question': 'B2603*4207=', 'answer': 10950821, 'gen': '11304501E'}
# 28600
# {'question': 'B4604+9927=', 'answer': 14531, 'gen': '14531E'}
# 28800
# {'question': 'B5877*1903=', 'answer': 11183931, 'gen': '10433591E'}
# 29000
# {'question': 'B4699/262=', 'answer': 17, 'gen': '18E'}
# 29200
# {'question': 'B966-8673=', 'answer': -7707, 'gen': '-7707E'}
# 29400
# {'question': 'B7474+9870=', 'answer': 17344, 'gen': '17344E'}
# 29600
# {'question': 'B8626*3010=', 'answer': 25964260, 'gen': '25854260E'}
# 29800
# {'question': 'B3803/4875=', 'answer': 0, 'gen': '0E'}
# 30000
# {'question': 'B9312*378=', 'answer': 3519936, 'gen': '3493176E'}
# 30200
# {'question': 'B7782*2339=', 'answer': 18202098, 'gen': '18460318E'}
# 30400
# {'question': 'B5623/7011=', 'answer': 0, 'gen': '0E'}
# 30600
# {'question': 'B4277-9483=', 'answer': -5206, 'gen': '-5206E'}
# 30800
# {'question': 'B3657/5358=', 'answer': 0, 'gen': '0E'}
# 31000
# {'question': 'B1481/4994=', 'answer': 0, 'gen': '0E'}
# 31200
# {'question': 'B4826*646=', 'answer': 3117596, 'gen': '3043996E'}
# 31400
# {'question': 'B9308/7807=', 'answer': 1, 'gen': '1E'}
# 31600
# {'question': 'B3345*9888=', 'answer': 33075360, 'gen': '33115660E'}
# 31800
# {'question': 'B8065*214=', 'answer': 1725910, 'gen': '1749010E'}
# 32000
# {'question': 'B8394/5708=', 'answer': 1, 'gen': '1E'}
# 32200
# {'question': 'B776-4879=', 'answer': -4103, 'gen': '-4103E'}
# 32400
# {'question': 'B4774-1685=', 'answer': 3089, 'gen': '3089E'}
# 32600
# {'question': 'B7565/4449=', 'answer': 1, 'gen': '1E'}
# 32800
# {'question': 'B366-5248=', 'answer': -4882, 'gen': '-4882E'}
# 33000
# {'question': 'B7144*9711=', 'answer': 69375384, 'gen': '70023744E'}
# 33200
# {'question': 'B5485/6476=', 'answer': 0, 'gen': '0E'}
# 33400
# {'question': 'B9976*6601=', 'answer': 65851576, 'gen': '66158476E'}
# 33600
# {'question': 'B6806*3226=', 'answer': 21956156, 'gen': '22885916E'}
# 33800
# {'question': 'B6151/9938=', 'answer': 0, 'gen': '0E'}
# 34000
# {'question': 'B2831/2897=', 'answer': 0, 'gen': '0E'}
# 34200
# {'question': 'B5950-2290=', 'answer': 3660, 'gen': '3660E'}
# 34400
# {'question': 'B2559-6699=', 'answer': -4140, 'gen': '-4140E'}
# 34600
# {'question': 'B8980+7959=', 'answer': 16939, 'gen': '16939E'}
# 34800
# {'question': 'B3041*2385=', 'answer': 7252785, 'gen': '7679725E'}
# 35000
# {'question': 'B6037-6709=', 'answer': -672, 'gen': '-672E'}
# 35200
# {'question': 'B8810/9215=', 'answer': 0, 'gen': '0E'}
# 35400
# {'question': 'B2287/3547=', 'answer': 0, 'gen': '0E'}
# 35600
# {'question': 'B76-4438=', 'answer': -4362, 'gen': '-4362E'}
# 35800
# {'question': 'B3627/8347=', 'answer': 0, 'gen': '0E'}
# 36000
# {'question': 'B871-9517=', 'answer': -8646, 'gen': '-8636E'}
# 36200
# {'question': 'B1336-1870=', 'answer': -534, 'gen': '-1534E'}
# 36400
# {'question': 'B2310*5128=', 'answer': 11845680, 'gen': '12364480E'}
# 36600
# {'question': 'B9111+3240=', 'answer': 12351, 'gen': '12351E'}
# 36800
# {'question': 'B4270*810=', 'answer': 3458700, 'gen': '3474700E'}
# 37000
# {'question': 'B1671-5943=', 'answer': -4272, 'gen': '-4272E'}
# 37200
# {'question': 'B2946-8551=', 'answer': -5605, 'gen': '-5605E'}
# 37400
# {'question': 'B7898*414=', 'answer': 3269772, 'gen': '3338312E'}
# 37600
# {'question': 'B488-8556=', 'answer': -8068, 'gen': '-8068E'}
# 37800
# {'question': 'B4516*5726=', 'answer': 25858616, 'gen': '26556496E'}
# 38000
# {'question': 'B3742+1292=', 'answer': 5034, 'gen': '5034E'}
# 38200
# {'question': 'B5441/6628=', 'answer': 0, 'gen': '0E'}
# 38400
# {'question': 'B6972*7446=', 'answer': 51913512, 'gen': '51701732E'}
# 38600
# {'question': 'B8626-7783=', 'answer': 843, 'gen': '843E'}
# 38800
# {'question': 'B2737*3691=', 'answer': 10102267, 'gen': '9739147E'}
# 39000
# {'question': 'B3800-7503=', 'answer': -3703, 'gen': '-3703E'}
# 39200
# {'question': 'B7466-9886=', 'answer': -2420, 'gen': '-2420E'}
# 39400
# {'question': 'B6347/6563=', 'answer': 0, 'gen': '0E'}
# 39600
# {'question': 'B7722/958=', 'answer': 8, 'gen': '7E'}
# 39800
# {'question': 'B298+633=', 'answer': 931, 'gen': '1921E'}
# 40000
# {'question': 'B9458-1794=', 'answer': 7664, 'gen': '7664E'}
# 40200
# {'question': 'B4327*3095=', 'answer': 13392065, 'gen': '13086665E'}
# 40400
# {'question': 'B5735*8077=', 'answer': 46321595, 'gen': '46427645E'}
# 40600
# {'question': 'B8073/9546=', 'answer': 0, 'gen': '0E'}
# 40800
# {'question': 'B6371-7315=', 'answer': -944, 'gen': '-944E'}
# 41000
# {'question': 'B9327/9780=', 'answer': 0, 'gen': '0E'}
# 41200
# {'question': 'B9896/30=', 'answer': 329, 'gen': '325E'}
# 41400
# {'question': 'B6715+3573=', 'answer': 10288, 'gen': '10288E'}
# 41600
# {'question': 'B6901/5871=', 'answer': 1, 'gen': '1E'}
# 41800
# {'question': 'B831-5903=', 'answer': -5072, 'gen': '-5072E'}
# 42000
# {'question': 'B6577*2132=', 'answer': 14022164, 'gen': '14128964E'}
# 42200
# {'question': 'B8257/1936=', 'answer': 4, 'gen': '4E'}
# 42400
# {'question': 'B8590*5775=', 'answer': 49607250, 'gen': '49043250E'}
# 42600
# {'question': 'B23*9800=', 'answer': 225400, 'gen': '221600E'}
# 42800
# {'question': 'B7168+3445=', 'answer': 10613, 'gen': '10613E'}
# 43000
# {'question': 'B7796*9920=', 'answer': 77336320, 'gen': '77330920E'}
# 43200
# {'question': 'B5806*6438=', 'answer': 37379028, 'gen': '37842588E'}
# 43400
# {'question': 'B5617+4801=', 'answer': 10418, 'gen': '10418E'}
# 43600
# {'question': 'B4975/510=', 'answer': 9, 'gen': '9E'}
# 43800
# {'question': 'B175*2140=', 'answer': 374500, 'gen': '372500E'}
# 44000
# {'question': 'B8231/184=', 'answer': 44, 'gen': '42E'}
# 44200
# {'question': 'B9231/4865=', 'answer': 1, 'gen': '1E'}
# 44400
# {'question': 'B9927/2454=', 'answer': 4, 'gen': '3E'}
# 44600
# {'question': 'B5152/4104=', 'answer': 1, 'gen': '1E'}
# 44800
# {'question': 'B4486*3355=', 'answer': 15050530, 'gen': '15094430E'}
# 45000
# {'question': 'B1025-2131=', 'answer': -1106, 'gen': '-1106E'}
# 45200
# {'question': 'B6726-1681=', 'answer': 5045, 'gen': '5045E'}
# 45400
# {'question': 'B5402*9344=', 'answer': 50476288, 'gen': '50209888E'}
# 45600
# {'question': 'B5051-2305=', 'answer': 2746, 'gen': '2746E'}
# 45800
# {'question': 'B2226+3452=', 'answer': 5678, 'gen': '5678E'}
# 46000
# {'question': 'B4740*1881=', 'answer': 8915940, 'gen': '8034340E'}
# 46200
# {'question': 'B9357*8667=', 'answer': 81097119, 'gen': '81321179E'}
# 46400
# {'question': 'B5579/5763=', 'answer': 0, 'gen': '0E'}
# 46600
# {'question': 'B7485+5873=', 'answer': 13358, 'gen': '13358E'}
# 46800
# {'question': 'B5798/428=', 'answer': 13, 'gen': '15E'}
# 47000
# {'question': 'B8551/5888=', 'answer': 1, 'gen': '1E'}
# 47200
# {'question': 'B6070-823=', 'answer': 5247, 'gen': '5247E'}
# 47400
# {'question': 'B9502/5011=', 'answer': 1, 'gen': '1E'}
# 47600
# {'question': 'B6962/3769=', 'answer': 1, 'gen': '1E'}
# 47800
# {'question': 'B4458*9724=', 'answer': 43349592, 'gen': '43462812E'}
# 48000
# {'question': 'B1058-3463=', 'answer': -2405, 'gen': '-2405E'}
# 48200
# {'question': 'B6764-7549=', 'answer': -785, 'gen': '-785E'}
# 48400
# {'question': 'B9030*3556=', 'answer': 32110680, 'gen': '31130280E'}
# 48600
# {'question': 'B4248-5315=', 'answer': -1067, 'gen': '-1067E'}
# 48800
# {'question': 'B9457+8415=', 'answer': 17872, 'gen': '17872E'}
# 49000
# {'question': 'B2779-4457=', 'answer': -1678, 'gen': '-1678E'}
# 49200
# {'question': 'B4951-8431=', 'answer': -3480, 'gen': '-3470E'}
# 49400
# {'question': 'B910+1076=', 'answer': 1986, 'gen': '1986E'}
# 49600
# {'question': 'B6457+7857=', 'answer': 14314, 'gen': '14314E'}
# 49800
# {'question': 'B6442/548=', 'answer': 11, 'gen': '11E'}
# 50000
# {'question': 'B1499-3830=', 'answer': -2331, 'gen': '-2331E'}
# 50200
# {'question': 'B2880/5963=', 'answer': 0, 'gen': '0E'}
# 50400
# {'question': 'B7309*686=', 'answer': 5013974, 'gen': '4957724E'}
# 50600
# {'question': 'B1330-3943=', 'answer': -2613, 'gen': '-2713E'}
# 50800
# {'question': 'B7665/847=', 'answer': 9, 'gen': '9E'}
# 51000
# {'question': 'B9558*5364=', 'answer': 51269112, 'gen': '51295772E'}
# 51200
# {'question': 'B276+8816=', 'answer': 9092, 'gen': '9092E'}
# 51400
# {'question': 'B2266/5438=', 'answer': 0, 'gen': '0E'}
# 51600
# {'question': 'B4401/619=', 'answer': 7, 'gen': '7E'}
# 51800
# {'question': 'B3085-7861=', 'answer': -4776, 'gen': '-4776E'}
# 52000
# {'question': 'B1979+819=', 'answer': 2798, 'gen': '2798E'}
# 52200
# {'question': 'B9189/4449=', 'answer': 2, 'gen': '1E'}
# 52400
# {'question': 'B3389+2487=', 'answer': 5876, 'gen': '5876E'}
# 52600
# {'question': 'B4810/3752=', 'answer': 1, 'gen': '1E'}
# 52800
# {'question': 'B9564-4809=', 'answer': 4755, 'gen': '4755E'}
# 53000
# {'question': 'B7310/1483=', 'answer': 4, 'gen': '4E'}
# 53200
# {'question': 'B90-3258=', 'answer': -3168, 'gen': '-3168E'}
# 53400
# {'question': 'B8294+6627=', 'answer': 14921, 'gen': '14921E'}
# 53600
# {'question': 'B2548*6000=', 'answer': 15288000, 'gen': '15188000E'}
# 53800
# {'question': 'B9393/7530=', 'answer': 1, 'gen': '1E'}
# 54000
# {'question': 'B7221-6733=', 'answer': 488, 'gen': '488E'}
# 54200
# {'question': 'B8059+3744=', 'answer': 11803, 'gen': '11803E'}
# 54400
# {'question': 'B2801+5028=', 'answer': 7829, 'gen': '7829E'}
# 54600
# {'question': 'B4288-8987=', 'answer': -4699, 'gen': '-4699E'}
# 54800
# {'question': 'B8612+7323=', 'answer': 15935, 'gen': '15935E'}
# 55000
# {'question': 'B5868/959=', 'answer': 6, 'gen': '5E'}
# 55200
# {'question': 'B9837*711=', 'answer': 6994107, 'gen': '6909567E'}
# 55400
# {'question': 'B7575-6154=', 'answer': 1421, 'gen': '1421E'}
# 55600
# {'question': 'B3474/9766=', 'answer': 0, 'gen': '0E'}
# 55800
# {'question': 'B2834/9653=', 'answer': 0, 'gen': '0E'}
# 56000
# {'question': 'B6664*501=', 'answer': 3338664, 'gen': '3318264E'}
# 56200
# {'question': 'B8700-35=', 'answer': 8665, 'gen': '8625E'}
# 56400
# {'question': 'B6148+3824=', 'answer': 9972, 'gen': '9972E'}
# 56600
# {'question': 'B9627+6933=', 'answer': 16560, 'gen': '16560E'}
# 56800
# {'question': 'B1973-3357=', 'answer': -1384, 'gen': '-1384E'}
# 57000
# {'question': 'B4623/8858=', 'answer': 0, 'gen': '0E'}
# 57200
# {'question': 'B3791/1675=', 'answer': 2, 'gen': '2E'}
# 57400
# {'question': 'B3447-9413=', 'answer': -5966, 'gen': '-5966E'}
# 57600
# {'question': 'B6297-5078=', 'answer': 1219, 'gen': '1219E'}
# 57800
# {'question': 'B5680*7097=', 'answer': 40310960, 'gen': '39608760E'}
# 58000
# {'question': 'B296/3035=', 'answer': 0, 'gen': '0E'}
# 58200
# {'question': 'B2666/9023=', 'answer': 0, 'gen': '0E'}
# 58400
# {'question': 'B5135*1457=', 'answer': 7481695, 'gen': '7148995E'}
# 58600
# {'question': 'B8259*9416=', 'answer': 77766744, 'gen': '77901144E'}
# 58800
# {'question': 'B5553+7187=', 'answer': 12740, 'gen': '12740E'}
# 59000
# {'question': 'B1541-7417=', 'answer': -5876, 'gen': '-5876E'}
# 59200
# {'question': 'B5714+9676=', 'answer': 15390, 'gen': '15390E'}
# 59400
# {'question': 'B9591*8097=', 'answer': 77658327, 'gen': '77838727E'}
# 59600
# {'question': 'B3836+4861=', 'answer': 8697, 'gen': '8697E'}
# 59800
# {'question': 'B1493*837=', 'answer': 1249641, 'gen': '1260441E'}
# 60000
# {'question': 'B5524*2417=', 'answer': 13351508, 'gen': '13789028E'}
# 60200
# {'question': 'B7852-7200=', 'answer': 652, 'gen': '652E'}
# 60400
# {'question': 'B2319-5344=', 'answer': -3025, 'gen': '-3025E'}
# 60600
# {'question': 'B1026*1841=', 'answer': 1888866, 'gen': '2021966E'}
# 60800
# {'question': 'B483-8657=', 'answer': -8174, 'gen': '-8174E'}
# 61000
# {'question': 'B5435/1990=', 'answer': 2, 'gen': '2E'}
# 61200
# {'question': 'B4710-1094=', 'answer': 3616, 'gen': '3616E'}
# 61400
# {'question': 'B1082+2922=', 'answer': 4004, 'gen': '4004E'}
# 61600
# {'question': 'B637+8619=', 'answer': 9256, 'gen': '9256E'}
# 61800
# {'question': 'B7198*716=', 'answer': 5153768, 'gen': '5186448E'}
# 62000
# {'question': 'B5742+900=', 'answer': 6642, 'gen': '6642E'}
# 62200
# {'question': 'B3274+3723=', 'answer': 6997, 'gen': '6997E'}
# 62400
# {'question': 'B6791*6325=', 'answer': 42953075, 'gen': '42604975E'}
# 62600
# {'question': 'B1967+616=', 'answer': 2583, 'gen': '2683E'}
# 62800
# {'question': 'B4594+9036=', 'answer': 13630, 'gen': '13630E'}
# 63000
# {'question': 'B6900*4289=', 'answer': 29594100, 'gen': '30865100E'}
# 63200
# {'question': 'B6218/2234=', 'answer': 2, 'gen': '2E'}
# 63400
# {'question': 'B8676-6055=', 'answer': 2621, 'gen': '2621E'}
# 63600
# {'question': 'B4828+2208=', 'answer': 7036, 'gen': '7036E'}
# 63800
# {'question': 'B5122*3909=', 'answer': 20021898, 'gen': '20425698E'}
# 64000
# {'question': 'B6986-4668=', 'answer': 2318, 'gen': '2318E'}
# 64200
# {'question': 'B4482-7475=', 'answer': -2993, 'gen': '-2993E'}
# 64400
# {'question': 'B8071/7141=', 'answer': 1, 'gen': '1E'}
# 64600
# {'question': 'B9937-593=', 'answer': 9344, 'gen': '9344E'}
# 64800
# {'question': 'B6054*4290=', 'answer': 25971660, 'gen': '25415460E'}
# 65000
# {'question': 'B806*2798=', 'answer': 2255188, 'gen': '2216872E'}
# 65200
# {'question': 'B5908/2264=', 'answer': 2, 'gen': '2E'}
# 65400
# {'question': 'B6409/9695=', 'answer': 0, 'gen': '0E'}
# 65600
# {'question': 'B9311*9399=', 'answer': 87514089, 'gen': '86820489E'}
# 65800
# {'question': 'B1582+1675=', 'answer': 3257, 'gen': '3257E'}
# 66000
# {'question': 'B7763/9261=', 'answer': 0, 'gen': '0E'}
# 66200
# {'question': 'B3166+8858=', 'answer': 12024, 'gen': '12024E'}
# 66400
# {'question': 'B901-8297=', 'answer': -7396, 'gen': '-7396E'}
# 66600
# {'question': 'B8185/5038=', 'answer': 1, 'gen': '1E'}
# 66800
# {'question': 'B1441*5741=', 'answer': 8272781, 'gen': '8393981E'}
# 67000
# {'question': 'B9453+5608=', 'answer': 15061, 'gen': '15061E'}
# 67200
# {'question': 'B417+9328=', 'answer': 9745, 'gen': '9745E'}
# 67400
# {'question': 'B1934*2407=', 'answer': 4655138, 'gen': '4853578E'}
# 67600
# {'question': 'B9274/8288=', 'answer': 1, 'gen': '1E'}
# 67800
# {'question': 'B3786-362=', 'answer': 3424, 'gen': '3424E'}
# 68000
# {'question': 'B586+474=', 'answer': 1060, 'gen': '1250E'}
# 68200
# {'question': 'B803-3674=', 'answer': -2871, 'gen': '-2871E'}
# 68400
# {'question': 'B5367*2223=', 'answer': 11930841, 'gen': '11725861E'}
# 68600
# {'question': 'B2042+9829=', 'answer': 11871, 'gen': '11871E'}
# 68800
# {'question': 'B4841*7909=', 'answer': 38287469, 'gen': '36485309E'}
# 69000
# {'question': 'B3065-1330=', 'answer': 1735, 'gen': '1735E'}
# 69200
# {'question': 'B6883*9015=', 'answer': 62050245, 'gen': '61834745E'}
# 69400
# {'question': 'B6057/6311=', 'answer': 0, 'gen': '0E'}
# 69600
# {'question': 'B7881-6168=', 'answer': 1713, 'gen': '1713E'}
# 69800
# {'question': 'B9360*5363=', 'answer': 50197680, 'gen': '50122080E'}
# 70000
# {'question': 'B8303/5433=', 'answer': 1, 'gen': '1E'}
# 70200
# {'question': 'B5153-8155=', 'answer': -3002, 'gen': '-3002E'}
# 70400
# {'question': 'B6172*520=', 'answer': 3209440, 'gen': '3255840E'}
# 70600
# {'question': 'B2408*2528=', 'answer': 6087424, 'gen': '6281936E'}
# 70800
# {'question': 'B6469-7614=', 'answer': -1145, 'gen': '-1145E'}
# 71000
# {'question': 'B1878*5685=', 'answer': 10676430, 'gen': '11272830E'}
# 71200
# {'question': 'B5073-3053=', 'answer': 2020, 'gen': '2020E'}
# 71400
# {'question': 'B5588/1585=', 'answer': 3, 'gen': '3E'}
# 71600
# {'question': 'B2025/7304=', 'answer': 0, 'gen': '0E'}
# 71800
# {'question': 'B5777-8501=', 'answer': -2724, 'gen': '-2724E'}
# 72000
# {'question': 'B3780-1452=', 'answer': 2328, 'gen': '2328E'}
# 72200
# {'question': 'B5995/2249=', 'answer': 2, 'gen': '2E'}
# 72400
# {'question': 'B5363*961=', 'answer': 5153843, 'gen': '5127593E'}
# 72600
# {'question': 'B29-3389=', 'answer': -3360, 'gen': '-3360E'}
# 72800
# {'question': 'B274/8371=', 'answer': 0, 'gen': '0E'}
# 73000
# {'question': 'B1722/6712=', 'answer': 0, 'gen': '0E'}
# 73200
# {'question': 'B2707/7791=', 'answer': 0, 'gen': '0E'}
# 73400
# {'question': 'B5317/3759=', 'answer': 1, 'gen': '1E'}
# 73600
# {'question': 'B4989*335=', 'answer': 1671315, 'gen': '1722565E'}
# 73800
# {'question': 'B9240-4672=', 'answer': 4568, 'gen': '4568E'}
# 74000
# {'question': 'B2860*9992=', 'answer': 28577120, 'gen': '28151320E'}
# 74200
# {'question': 'B32*1847=', 'answer': 59104, 'gen': '58709E'}
# 74400
# {'question': 'B1911/2157=', 'answer': 0, 'gen': '0E'}
# 74600
# {'question': 'B8202/9570=', 'answer': 0, 'gen': '0E'}
# 74800
# {'question': 'B1450+4235=', 'answer': 5685, 'gen': '5685E'}
# 75000
# {'question': 'B2477-7824=', 'answer': -5347, 'gen': '-5347E'}
# 75200
# {'question': 'B7756+5422=', 'answer': 13178, 'gen': '13178E'}
# 75400
# {'question': 'B5303*6629=', 'answer': 35153587, 'gen': '35147807E'}
# 75600
# {'question': 'B3538*4457=', 'answer': 15768866, 'gen': '16119986E'}
# 75800
# {'question': 'B3323-1876=', 'answer': 1447, 'gen': '1447E'}
# 76000
# {'question': 'B8720/8120=', 'answer': 1, 'gen': '1E'}
# 76200
# {'question': 'B7074+8305=', 'answer': 15379, 'gen': '15379E'}
# 76400
# {'question': 'B1450/520=', 'answer': 2, 'gen': '3E'}
# 76600
# {'question': 'B3741-8118=', 'answer': -4377, 'gen': '-4377E'}
# 76800
# {'question': 'B3047+6460=', 'answer': 9507, 'gen': '9507E'}
# 77000
# {'question': 'B9586-7392=', 'answer': 2194, 'gen': '2194E'}
# 77200
# {'question': 'B4037/9934=', 'answer': 0, 'gen': '0E'}
# 77400
# {'question': 'B5645+558=', 'answer': 6203, 'gen': '6193E'}
# 77600
# {'question': 'B1366+979=', 'answer': 2345, 'gen': '2345E'}
# 77800
# {'question': 'B7086+4413=', 'answer': 11499, 'gen': '11499E'}
# 78000
# {'question': 'B8322+361=', 'answer': 8683, 'gen': '8683E'}
# 78200
# {'question': 'B4141*6113=', 'answer': 25313933, 'gen': '26210693E'}
# 78400
# {'question': 'B7279+2134=', 'answer': 9413, 'gen': '9413E'}
# 78600
# {'question': 'B9455*7780=', 'answer': 73559900, 'gen': '73260900E'}
# 78800
# {'question': 'B7114/7281=', 'answer': 0, 'gen': '0E'}
# 79000
# {'question': 'B6433*322=', 'answer': 2071426, 'gen': '2144526E'}
# 79200
# {'question': 'B9088/3293=', 'answer': 2, 'gen': '2E'}
# 79400
# {'question': 'B9258-2419=', 'answer': 6839, 'gen': '6839E'}
# 79600
# {'question': 'B7919-5940=', 'answer': 1979, 'gen': '1979E'}
# 79800
# {'question': 'B9910+1747=', 'answer': 11657, 'gen': '11657E'}
# 80000
# {'question': 'B1549-2163=', 'answer': -614, 'gen': '-514E'}
# 80200
# {'question': 'B9628+2550=', 'answer': 12178, 'gen': '12178E'}
# 80400
# {'question': 'B7906+9102=', 'answer': 17008, 'gen': '17008E'}
# 80600
# {'question': 'B2024+9337=', 'answer': 11361, 'gen': '11361E'}
# 80800
# {'question': 'B174+7687=', 'answer': 7861, 'gen': '7861E'}
# 81000
# {'question': 'B9026+2788=', 'answer': 11814, 'gen': '11814E'}
# 81200
# {'question': 'B2074-1756=', 'answer': 318, 'gen': '318E'}
# 81400
# {'question': 'B9753-8797=', 'answer': 956, 'gen': '956E'}
# 81600
# {'question': 'B6000*5527=', 'answer': 33162000, 'gen': '33122000E'}
# 81800
# {'question': 'B6730*2712=', 'answer': 18251760, 'gen': '18101960E'}
# 82000
# {'question': 'B934-3538=', 'answer': -2604, 'gen': '-2604E'}
# 82200
# {'question': 'B8593-2923=', 'answer': 5670, 'gen': '5670E'}
# 82400
# {'question': 'B3777-8336=', 'answer': -4559, 'gen': '-4559E'}
# 82600
# {'question': 'B6949*4865=', 'answer': 33806885, 'gen': '33992985E'}
# 82800
# {'question': 'B1831/4061=', 'answer': 0, 'gen': '0E'}
# 83000
# {'question': 'B6674*9046=', 'answer': 60373004, 'gen': '59774304E'}
# 83200
# {'question': 'B7875+7236=', 'answer': 15111, 'gen': '15111E'}
# 83400
# {'question': 'B7528+822=', 'answer': 8350, 'gen': '8340E'}
# 83600
# {'question': 'B7974/6090=', 'answer': 1, 'gen': '1E'}
# 83800
# {'question': 'B3244-185=', 'answer': 3059, 'gen': '2959E'}
# 84000
# {'question': 'B4490*1402=', 'answer': 6294980, 'gen': '6192280E'}
# 84200
# {'question': 'B8136+6438=', 'answer': 14574, 'gen': '14574E'}
# 84400
# {'question': 'B3934*6886=', 'answer': 27089524, 'gen': '27555744E'}
# 84600
# {'question': 'B264+3240=', 'answer': 3504, 'gen': '3504E'}
# 84800
# {'question': 'B698*7977=', 'answer': 5567946, 'gen': '5496006E'}
# 85000
# {'question': 'B82/6975=', 'answer': 0, 'gen': '0E'}
# 85200
# {'question': 'B7239*5876=', 'answer': 42536364, 'gen': '42527824E'}
# 85400
# {'question': 'B5852/5158=', 'answer': 1, 'gen': '1E'}
# 85600
# {'question': 'B8576-2071=', 'answer': 6505, 'gen': '6505E'}
# 85800
# {'question': 'B6195*3259=', 'answer': 20189505, 'gen': '19839805E'}
# 86000
# {'question': 'B4747/2049=', 'answer': 2, 'gen': '2E'}
# 86200
# {'question': 'B7738*277=', 'answer': 2143426, 'gen': '2152846E'}
# 86400
# {'question': 'B3556*9229=', 'answer': 32818324, 'gen': '33151524E'}
# 86600
# {'question': 'B6148/9555=', 'answer': 0, 'gen': '0E'}
# 86800
# {'question': 'B9660-2964=', 'answer': 6696, 'gen': '6696E'}
# 87000
# {'question': 'B4606-7888=', 'answer': -3282, 'gen': '-3282E'}
# 87200
# {'question': 'B7421*1039=', 'answer': 7710419, 'gen': '7571019E'}
# 87400
# {'question': 'B7504/2463=', 'answer': 3, 'gen': '3E'}
# 87600
# {'question': 'B9881+5432=', 'answer': 15313, 'gen': '15313E'}
# 87800
# {'question': 'B1531+3887=', 'answer': 5418, 'gen': '5418E'}
# 88000
# {'question': 'B1289-8329=', 'answer': -7040, 'gen': '-7040E'}
# 88200
# {'question': 'B4915/1698=', 'answer': 2, 'gen': '2E'}
# 88400
# {'question': 'B9543-4095=', 'answer': 5448, 'gen': '5448E'}
# 88600
# {'question': 'B7895-6587=', 'answer': 1308, 'gen': '1308E'}
# 88800
# {'question': 'B9541-7116=', 'answer': 2425, 'gen': '2425E'}
# 89000
# {'question': 'B9034-7587=', 'answer': 1447, 'gen': '1447E'}
# 89200
# {'question': 'B330-3812=', 'answer': -3482, 'gen': '-3482E'}
# 89400
# {'question': 'B744*1135=', 'answer': 844440, 'gen': '869490E'}
# 89600
# {'question': 'B763-8820=', 'answer': -8057, 'gen': '-8057E'}
# 89800
# {'question': 'B3229-3029=', 'answer': 200, 'gen': '200E'}
# 90000
# {'question': 'B6758-6975=', 'answer': -217, 'gen': '-217E'}
# 90200
# {'question': 'B7996/5030=', 'answer': 1, 'gen': '1E'}
# 90400
# {'question': 'B6842-520=', 'answer': 6322, 'gen': '6322E'}
# 90600
# {'question': 'B9657-7128=', 'answer': 2529, 'gen': '2529E'}
# 90800
# {'question': 'B3789+6896=', 'answer': 10685, 'gen': '10685E'}
# 91000
# {'question': 'B4273-8605=', 'answer': -4332, 'gen': '-4332E'}
# 91200
# {'question': 'B878+2131=', 'answer': 3009, 'gen': '3009E'}
# 91400
# {'question': 'B2401*8632=', 'answer': 20725432, 'gen': '20498832E'}
# 91600
# {'question': 'B1670/4793=', 'answer': 0, 'gen': '0E'}
# 91800
# {'question': 'B2487+860=', 'answer': 3347, 'gen': '3347E'}
# 92000
# {'question': 'B6842-7310=', 'answer': -468, 'gen': '-468E'}
# 92200
# {'question': 'B6383*2917=', 'answer': 18619211, 'gen': '18577331E'}
# 92400
# {'question': 'B40/342=', 'answer': 0, 'gen': '0E'}
# 92600
# {'question': 'B5470/1735=', 'answer': 3, 'gen': '2E'}
# 92800
# {'question': 'B899+9261=', 'answer': 10160, 'gen': '10160E'}
# 93000
# {'question': 'B8644+2257=', 'answer': 10901, 'gen': '10901E'}
# 93200
# {'question': 'B9796/3035=', 'answer': 3, 'gen': '3E'}
# 93400
# {'question': 'B8267+792=', 'answer': 9059, 'gen': '8969E'}
# 93600
# {'question': 'B1427*175=', 'answer': 249725, 'gen': '239375E'}
# 93800
# {'question': 'B1023-3501=', 'answer': -2478, 'gen': '-2478E'}
# 94000
# {'question': 'B4712-6737=', 'answer': -2025, 'gen': '-2025E'}
# 94200
# {'question': 'B4865-212=', 'answer': 4653, 'gen': '4653E'}
# 94400
# {'question': 'B5474-4184=', 'answer': 1290, 'gen': '1290E'}
# 94600
# {'question': 'B1702/5277=', 'answer': 0, 'gen': '0E'}
# 94800
# {'question': 'B7617+2075=', 'answer': 9692, 'gen': '9692E'}
# 95000
# {'question': 'B8241*6005=', 'answer': 49487205, 'gen': '49057005E'}
# 95200
# {'question': 'B2179/7819=', 'answer': 0, 'gen': '0E'}
# 95400
# {'question': 'B8841*8265=', 'answer': 73070865, 'gen': '73570165E'}
# 95600
# {'question': 'B3017+1885=', 'answer': 4902, 'gen': '4902E'}
# 95800
# {'question': 'B7498+4134=', 'answer': 11632, 'gen': '11632E'}
# 96000
# {'question': 'B6408*9222=', 'answer': 59094576, 'gen': '59185116E'}
# 96200
# {'question': 'B2824+6729=', 'answer': 9553, 'gen': '9553E'}
# 96400
# {'question': 'B1300+4438=', 'answer': 5738, 'gen': '5738E'}
# 96600
# {'question': 'B246*2797=', 'answer': 688062, 'gen': '661762E'}
# 96800
# {'question': 'B4186*7224=', 'answer': 30239664, 'gen': '32115504E'}
# 97000
# {'question': 'B6926/8459=', 'answer': 0, 'gen': '0E'}
# 97200
# {'question': 'B6227+7128=', 'answer': 13355, 'gen': '13355E'}
# 97400
# {'question': 'B4680*7100=', 'answer': 33228000, 'gen': '32208000E'}
# 97600
# {'question': 'B7068-9269=', 'answer': -2201, 'gen': '-2201E'}
# 97800
# {'question': 'B4985-234=', 'answer': 4751, 'gen': '4751E'}
# 98000
# {'question': 'B5355*3535=', 'answer': 18929925, 'gen': '20918275E'}
# 98200
# {'question': 'B823-3518=', 'answer': -2695, 'gen': '-2695E'}
# 98400
# {'question': 'B3968+9335=', 'answer': 13303, 'gen': '13303E'}
# 98600
# {'question': 'B1050+8851=', 'answer': 9901, 'gen': '9901E'}
# 98800
# {'question': 'B5684/2834=', 'answer': 2, 'gen': '2E'}
# 99000
# {'question': 'B254/5325=', 'answer': 0, 'gen': '0E'}
# 99200
# {'question': 'B6640-1796=', 'answer': 4844, 'gen': '4844E'}
# 99400
# {'question': 'B6319-2799=', 'answer': 3520, 'gen': '3520E'}
# 99600
# {'question': 'B490/9954=', 'answer': 0, 'gen': '0E'}
# 99800
# {'question': 'B2609-2269=', 'answer': 340, 'gen': '340E'}
# 100000
# {'question': 'B9883-9145=', 'answer': 738, 'gen': '738E'}
# 100200
# {'question': 'B1955-6819=', 'answer': -4864, 'gen': '-4864E'}
# 100400
# {'question': 'B4229-2176=', 'answer': 2053, 'gen': '2053E'}
# 100600
# {'question': 'B9695+5134=', 'answer': 14829, 'gen': '14829E'}
# 100800
# {'question': 'B8486*2161=', 'answer': 18338246, 'gen': '18351846E'}
# 101000
# {'question': 'B6698+8016=', 'answer': 14714, 'gen': '14714E'}
# 101200
# {'question': 'B7097+2252=', 'answer': 9349, 'gen': '9349E'}
# 101400
# {'question': 'B3052-7506=', 'answer': -4454, 'gen': '-4454E'}
# 101600
# {'question': 'B2146*1998=', 'answer': 4287708, 'gen': '4320968E'}
# 101800
# {'question': 'B724*6581=', 'answer': 4764644, 'gen': '4790204E'}
# 102000
# {'question': 'B4841*7939=', 'answer': 38432699, 'gen': '38194819E'}
# 102200
# {'question': 'B8186*6845=', 'answer': 56033170, 'gen': '56574070E'}
# 102400
# {'question': 'B955*4732=', 'answer': 4519060, 'gen': '4500260E'}
# 102600
# {'question': 'B4163*8052=', 'answer': 33520476, 'gen': '34086696E'}
# 102800
# {'question': 'B9669+1316=', 'answer': 10985, 'gen': '10985E'}
# 103000
# {'question': 'B2065-3520=', 'answer': -1455, 'gen': '-1455E'}
# 103200
# {'question': 'B3373-3937=', 'answer': -564, 'gen': '-564E'}
# 103400
# {'question': 'B8578+1723=', 'answer': 10301, 'gen': '10301E'}
# 103600
# {'question': 'B5980+7874=', 'answer': 13854, 'gen': '13854E'}
# 103800
# {'question': 'B7162/7678=', 'answer': 0, 'gen': '0E'}
# 104000
# {'question': 'B6518-4271=', 'answer': 2247, 'gen': '2247E'}
# 104200
# {'question': 'B2304+6321=', 'answer': 8625, 'gen': '8625E'}
# 104400
# {'question': 'B8889/247=', 'answer': 35, 'gen': '37E'}
# 104600
# {'question': 'B9854+2417=', 'answer': 12271, 'gen': '12271E'}
# 104800
# {'question': 'B5140-4233=', 'answer': 907, 'gen': '907E'}
# 105000
# {'question': 'B6709+7548=', 'answer': 14257, 'gen': '14257E'}
# 105200
# {'question': 'B5891*2103=', 'answer': 12388773, 'gen': '12998073E'}
# 105400
# {'question': 'B3261/7970=', 'answer': 0, 'gen': '0E'}
# 105600
# {'question': 'B2358/1298=', 'answer': 1, 'gen': '1E'}
# 105800
# {'question': 'B2587*3813=', 'answer': 9864231, 'gen': '10008011E'}
# 106000
# {'question': 'B6352/6051=', 'answer': 1, 'gen': '1E'}
# 106200
# {'question': 'B782/1780=', 'answer': 0, 'gen': '0E'}
# 106400
# {'question': 'B10*5504=', 'answer': 55040, 'gen': '55240E'}
# 106600
# {'question': 'B7558-9395=', 'answer': -1837, 'gen': '-837E'}
# 106800
# {'question': 'B5079*4036=', 'answer': 20498844, 'gen': '20861204E'}
# 107000
# {'question': 'B4987+4757=', 'answer': 9744, 'gen': '9744E'}
# 107200
# {'question': 'B2270-5201=', 'answer': -2931, 'gen': '-2931E'}
# 107400
# {'question': 'B5100*9086=', 'answer': 46338600, 'gen': '47252600E'}
# 107600
# {'question': 'B9678*2958=', 'answer': 28627524, 'gen': '28797844E'}
# 107800
# {'question': 'B9939/3280=', 'answer': 3, 'gen': '3E'}
# 108000
# {'question': 'B3711+4646=', 'answer': 8357, 'gen': '8357E'}
# 108200
# {'question': 'B7950+2655=', 'answer': 10605, 'gen': '10605E'}
# 108400
# {'question': 'B884*838=', 'answer': 740792, 'gen': '738792E'}
# 108600
# {'question': 'B8036*1701=', 'answer': 13669236, 'gen': '13664236E'}
# 108800
# {'question': 'B4653+9359=', 'answer': 14012, 'gen': '14012E'}
# 109000
# {'question': 'B8664+1671=', 'answer': 10335, 'gen': '10335E'}
# 109200
# {'question': 'B969+4743=', 'answer': 5712, 'gen': '5712E'}
# 109400
# {'question': 'B8871*7783=', 'answer': 69042993, 'gen': '68712293E'}
# 109600
# {'question': 'B6142/7308=', 'answer': 0, 'gen': '0E'}
# 109800
# {'question': 'B9973+2213=', 'answer': 12186, 'gen': '12186E'}
# 110000
# {'question': 'B9551-7151=', 'answer': 2400, 'gen': '2400E'}
# 110200
# {'question': 'B4875+1918=', 'answer': 6793, 'gen': '6793E'}
# 110400
# {'question': 'B1473+2362=', 'answer': 3835, 'gen': '3835E'}
# 110600
# {'question': 'B6060+8986=', 'answer': 15046, 'gen': '15046E'}
# 110800
# {'question': 'B3620*4365=', 'answer': 15801300, 'gen': '15772300E'}
# 111000
# {'question': 'B3007+6476=', 'answer': 9483, 'gen': '9483E'}
# 111200
# {'question': 'B6315-1558=', 'answer': 4757, 'gen': '4757E'}
# 111400
# {'question': 'B7368/1482=', 'answer': 4, 'gen': '5E'}
# 111600
# {'question': 'B850*9385=', 'answer': 7977250, 'gen': '8005750E'}
# 111800
# {'question': 'B7485/3580=', 'answer': 2, 'gen': '2E'}
# 112000
# {'question': 'B7790+9071=', 'answer': 16861, 'gen': '16861E'}
# 112200
# {'question': 'B1242*1623=', 'answer': 2015766, 'gen': '2039066E'}
# 112400
# {'question': 'B4376-1625=', 'answer': 2751, 'gen': '2751E'}
# 112600
# {'question': 'B7888-4819=', 'answer': 3069, 'gen': '3069E'}
# 112800
# {'question': 'B7894-4059=', 'answer': 3835, 'gen': '3835E'}
# 113000
# {'question': 'B5769-8790=', 'answer': -3021, 'gen': '-3021E'}
# 113200
# {'question': 'B7985/9105=', 'answer': 0, 'gen': '0E'}
# 113400
# {'question': 'B3509/5347=', 'answer': 0, 'gen': '0E'}
# 113600
# {'question': 'B2084*2547=', 'answer': 5307948, 'gen': '5410328E'}
# 113800
# {'question': 'B9512+5374=', 'answer': 14886, 'gen': '14886E'}
# 114000
# {'question': 'B4354*9293=', 'answer': 40461722, 'gen': '40205962E'}
# 114200
# {'question': 'B6997-9650=', 'answer': -2653, 'gen': '-2653E'}
# 114400
# {'question': 'B1836/4896=', 'answer': 0, 'gen': '0E'}
# 114600
# {'question': 'B5719+8184=', 'answer': 13903, 'gen': '13903E'}
# 114800
# {'question': 'B1351-9532=', 'answer': -8181, 'gen': '-8181E'}
# 115000
# {'question': 'B4462*473=', 'answer': 2110526, 'gen': '2174166E'}
# 115200
# {'question': 'B4197/5134=', 'answer': 0, 'gen': '0E'}
# 115400
# {'question': 'B2897/1042=', 'answer': 2, 'gen': '2E'}
# 115600
# {'question': 'B2930-5279=', 'answer': -2349, 'gen': '-2349E'}
# 115800
# {'question': 'B4725/1856=', 'answer': 2, 'gen': '2E'}
# 116000
# {'question': 'B9911/425=', 'answer': 23, 'gen': '25E'}
# 116200
# {'question': 'B3508/2186=', 'answer': 1, 'gen': '1E'}
# 116400
# {'question': 'B576/4890=', 'answer': 0, 'gen': '0E'}
# 116600
# {'question': 'B7494-970=', 'answer': 6524, 'gen': '6524E'}
# 116800
# {'question': 'B5792-2469=', 'answer': 3323, 'gen': '3323E'}
# 117000
# {'question': 'B3899/8144=', 'answer': 0, 'gen': '0E'}
# 117200
# {'question': 'B3822-2697=', 'answer': 1125, 'gen': '1125E'}
# 117400
# {'question': 'B6197+2535=', 'answer': 8732, 'gen': '8732E'}
# 117600
# {'question': 'B8646+1001=', 'answer': 9647, 'gen': '9647E'}
# 117800
# {'question': 'B9299-5250=', 'answer': 4049, 'gen': '4049E'}
# 118000
# {'question': 'B3560/7129=', 'answer': 0, 'gen': '0E'}
# 118200
# {'question': 'B1695*4018=', 'answer': 6810510, 'gen': '6844710E'}
# 118400
# {'question': 'B4923*8291=', 'answer': 40816593, 'gen': '40088933E'}
# 118600
# {'question': 'B7211+3156=', 'answer': 10367, 'gen': '10367E'}
# 118800
# {'question': 'B3762*5871=', 'answer': 22086702, 'gen': '21254902E'}
# 119000
# {'question': 'B6041/1804=', 'answer': 3, 'gen': '3E'}
# 119200
# {'question': 'B8430+2541=', 'answer': 10971, 'gen': '10971E'}
# 119400
# {'question': 'B7952*8169=', 'answer': 64959888, 'gen': '65291888E'}
# 119600
# {'question': 'B5998*7494=', 'answer': 44949012, 'gen': '44885812E'}
# 119800
# {'question': 'B4302*6280=', 'answer': 27016560, 'gen': '27234160E'}
# 120000
# {'question': 'B1805+9884=', 'answer': 11689, 'gen': '11689E'}
# 120200
# {'question': 'B3395/118=', 'answer': 28, 'gen': '24E'}
# 120400
# {'question': 'B9924/929=', 'answer': 10, 'gen': '10E'}
# 120600
# {'question': 'B3651+9467=', 'answer': 13118, 'gen': '13118E'}
# 120800
# {'question': 'B4658-7442=', 'answer': -2784, 'gen': '-2784E'}
# 121000
# {'question': 'B3243+1275=', 'answer': 4518, 'gen': '4518E'}
# 121200
# {'question': 'B3373+9117=', 'answer': 12490, 'gen': '12490E'}
# 121400
# {'question': 'B5046-3208=', 'answer': 1838, 'gen': '1838E'}
# 121600
# {'question': 'B3263+739=', 'answer': 4002, 'gen': '4002E'}
# 121800
# {'question': 'B4762+948=', 'answer': 5710, 'gen': '5690E'}
# 122000
# {'question': 'B6882*3341=', 'answer': 22992762, 'gen': '23415522E'}
# 122200
# {'question': 'B564+3800=', 'answer': 4364, 'gen': '4364E'}
# 122400
# {'question': 'B9593/4712=', 'answer': 2, 'gen': '2E'}
# 122600
# {'question': 'B6072-5761=', 'answer': 311, 'gen': '311E'}
# 122800
# {'question': 'B9648*1710=', 'answer': 16498080, 'gen': '16761080E'}
# 123000
# {'question': 'B6465+7340=', 'answer': 13805, 'gen': '13805E'}
# 123200
# {'question': 'B6536/6892=', 'answer': 0, 'gen': '0E'}
# 123400
# {'question': 'B516/5859=', 'answer': 0, 'gen': '0E'}
# 123600
# {'question': 'B7389*6560=', 'answer': 48471840, 'gen': '48299640E'}
# 123800
# {'question': 'B357+8549=', 'answer': 8906, 'gen': '8906E'}
# 124000
# {'question': 'B570-8704=', 'answer': -8134, 'gen': '-8134E'}
# 124200
# {'question': 'B7699+8001=', 'answer': 15700, 'gen': '15700E'}
# 124400
# {'question': 'B5733+9054=', 'answer': 14787, 'gen': '14787E'}
# 124600
# {'question': 'B7337*3254=', 'answer': 23874598, 'gen': '24860498E'}
# 124800
# {'question': 'B8534-3007=', 'answer': 5527, 'gen': '5527E'}
# 125000
# {'question': 'B9238+2646=', 'answer': 11884, 'gen': '11884E'}
# 125200
# {'question': 'B8461+153=', 'answer': 8614, 'gen': '8614E'}
# 125400
# {'question': 'B8591-6131=', 'answer': 2460, 'gen': '2460E'}
# 125600
# {'question': 'B6962-8293=', 'answer': -1331, 'gen': '-1331E'}
# 125800
# {'question': 'B1619-2076=', 'answer': -457, 'gen': '-P47E'}
# 126000
# {'question': 'B946*5834=', 'answer': 5518964, 'gen': '5532904E'}
# 126200
# {'question': 'B4911-9866=', 'answer': -4955, 'gen': '-4955E'}
# 126400
# {'question': 'B56-3500=', 'answer': -3444, 'gen': '-3444E'}
# 126600
# {'question': 'B7973/6314=', 'answer': 1, 'gen': '1E'}
# 126800
# {'question': 'B7202/8655=', 'answer': 0, 'gen': '0E'}
# 127000
# {'question': 'B5276-1771=', 'answer': 3505, 'gen': '3505E'}
# 127200
# {'question': 'B686*9746=', 'answer': 6685756, 'gen': '6692244E'}
# 127400
# {'question': 'B4995/7750=', 'answer': 0, 'gen': '0E'}
# 127600
# {'question': 'B8377/900=', 'answer': 9, 'gen': '9E'}
# 127800
# {'question': 'B6099+7580=', 'answer': 13679, 'gen': '13679E'}
# 128000
# {'question': 'B8620-6015=', 'answer': 2605, 'gen': '2605E'}
# 128200
# {'question': 'B7367*8240=', 'answer': 60704080, 'gen': '60554680E'}
# 128400
# {'question': 'B4784*211=', 'answer': 1009424, 'gen': '1038684E'}
# 128600
# {'question': 'B2807*1317=', 'answer': 3696819, 'gen': '3949179E'}
# 128800
# {'question': 'B7982/8930=', 'answer': 0, 'gen': '0E'}
# 129000
# {'question': 'B3718+7322=', 'answer': 11040, 'gen': '11040E'}
# 129200
# {'question': 'B3723*2077=', 'answer': 7732671, 'gen': '7827571E'}
# 129400
# {'question': 'B6330*4182=', 'answer': 26472060, 'gen': '26657260E'}
# 129600
# {'question': 'B4452*5542=', 'answer': 24672984, 'gen': '25650944E'}
# 129800
# {'question': 'B8556-2942=', 'answer': 5614, 'gen': '5614E'}
# 130000
# {'question': 'B8055/4668=', 'answer': 1, 'gen': '1E'}
# 130200
# {'question': 'B6542/3618=', 'answer': 1, 'gen': '1E'}
# 130400
# {'question': 'B8672*4739=', 'answer': 41096608, 'gen': '41111788E'}
# 130600
# {'question': 'B4042/4037=', 'answer': 1, 'gen': '1E'}
# 130800
# {'question': 'B4606+4221=', 'answer': 8827, 'gen': '8827E'}
# 131000
# {'question': 'B6451/2806=', 'answer': 2, 'gen': '2E'}
# 131200
# {'question': 'B1827+2008=', 'answer': 3835, 'gen': '3835E'}
# 131400
# {'question': 'B3686+5082=', 'answer': 8768, 'gen': '8768E'}
# 131600
# {'question': 'B9908/4676=', 'answer': 2, 'gen': '2E'}
# 131800
# {'question': 'B965+3103=', 'answer': 4068, 'gen': '4068E'}
# 132000
# {'question': 'B5631/3815=', 'answer': 1, 'gen': '1E'}
# 132200
# {'question': 'B1214/8230=', 'answer': 0, 'gen': '0E'}
# 132400
# {'question': 'B7515-5764=', 'answer': 1751, 'gen': '1751E'}
# 132600
# {'question': 'B6852*5838=', 'answer': 40001976, 'gen': '40037016E'}
# 132800
# {'question': 'B958*5151=', 'answer': 4934658, 'gen': '4966058E'}
# 133000
# {'question': 'B746/2494=', 'answer': 0, 'gen': '0E'}
# 133200
# {'question': 'B7146+2294=', 'answer': 9440, 'gen': '9440E'}
# 133400
# {'question': 'B772/9350=', 'answer': 0, 'gen': '0E'}
# 133600
# {'question': 'B3614/3872=', 'answer': 0, 'gen': '0E'}
# 133800
# {'question': 'B8528-1301=', 'answer': 7227, 'gen': '7227E'}
# 134000
# {'question': 'B1779+9942=', 'answer': 11721, 'gen': '11721E'}
# 134200
# {'question': 'B1736*8602=', 'answer': 14933072, 'gen': '15004652E'}
# 134400
# {'question': 'B7765*1334=', 'answer': 10358510, 'gen': '9581510E'}
# 134600
# {'question': 'B7887-7227=', 'answer': 660, 'gen': '660E'}
# 134800
# {'question': 'B5142*3399=', 'answer': 17477658, 'gen': '17836298E'}
# 135000
# {'question': 'B6083+9040=', 'answer': 15123, 'gen': '15123E'}
# 135200
# {'question': 'B9378-7514=', 'answer': 1864, 'gen': '1864E'}
# 135400
# {'question': 'B4582-7901=', 'answer': -3319, 'gen': '-3319E'}
# 135600
# {'question': 'B1085+6710=', 'answer': 7795, 'gen': '7795E'}
# 135800
# {'question': 'B4376*1019=', 'answer': 4459144, 'gen': '4068064E'}
# 136000
# {'question': 'B7030*8098=', 'answer': 56928940, 'gen': '57391340E'}
# 136200
# {'question': 'B9501-6541=', 'answer': 2960, 'gen': '2960E'}
# 136400
# {'question': 'B3014+8819=', 'answer': 11833, 'gen': '11833E'}
# 136600
# {'question': 'B9893-5130=', 'answer': 4763, 'gen': '4763E'}
# 136800
# {'question': 'B5594/5965=', 'answer': 0, 'gen': '0E'}
# 137000
# {'question': 'B5273-7333=', 'answer': -2060, 'gen': '-2060E'}
# 137200
# {'question': 'B4843+3489=', 'answer': 8332, 'gen': '8332E'}
# 137400
# {'question': 'B8715/4394=', 'answer': 1, 'gen': '2E'}
# 137600
# {'question': 'B1663+3292=', 'answer': 4955, 'gen': '4955E'}
# 137800
# {'question': 'B5657+3280=', 'answer': 8937, 'gen': '8937E'}
# 138000
# {'question': 'B3323-5967=', 'answer': -2644, 'gen': '-2644E'}
# 138200
# {'question': 'B8980*1784=', 'answer': 16020320, 'gen': '15510120E'}
# 138400
# {'question': 'B5078/930=', 'answer': 5, 'gen': '5E'}
# 138600
# {'question': 'B5172*4790=', 'answer': 24773880, 'gen': '24973080E'}
# 138800
# {'question': 'B8501/6160=', 'answer': 1, 'gen': '1E'}
# 139000
# {'question': 'B5083-4270=', 'answer': 813, 'gen': '813E'}
# 139200
# {'question': 'B4620*9370=', 'answer': 43289400, 'gen': '43230400E'}
# 139400
# {'question': 'B983+1357=', 'answer': 2340, 'gen': '2340E'}
# 139600
# {'question': 'B5938/7401=', 'answer': 0, 'gen': '0E'}
# 139800
# {'question': 'B6747+4730=', 'answer': 11477, 'gen': '11477E'}
# 140000
# {'question': 'B4405-2440=', 'answer': 1965, 'gen': '1965E'}
# 140200
# {'question': 'B9044-1980=', 'answer': 7064, 'gen': '7064E'}
# 140400
# {'question': 'B6319+5594=', 'answer': 11913, 'gen': '11913E'}
# 140600
# {'question': 'B2964/6920=', 'answer': 0, 'gen': '0E'}
# 140800
# {'question': 'B9455-2476=', 'answer': 6979, 'gen': '6979E'}
# 141000
# {'question': 'B2996*2700=', 'answer': 8089200, 'gen': '7765200E'}
# 141200
# {'question': 'B1898*4821=', 'answer': 9150258, 'gen': '9135438E'}
# 141400
# {'question': 'B4014/8456=', 'answer': 0, 'gen': '0E'}
# 141600
# {'question': 'B891/7572=', 'answer': 0, 'gen': '0E'}
# 141800
# {'question': 'B7534/9326=', 'answer': 0, 'gen': '0E'}
# 142000
# {'question': 'B2640*1602=', 'answer': 4229280, 'gen': '4579280E'}
# 142200
# {'question': 'B917/2857=', 'answer': 0, 'gen': '0E'}
# 142400
# {'question': 'B8722+590=', 'answer': 9312, 'gen': '9312E'}
# 142600
# {'question': 'B3392/1785=', 'answer': 1, 'gen': '1E'}
# 142800
# {'question': 'B665+2733=', 'answer': 3398, 'gen': '3398E'}
# 143000
# {'question': 'B7623-3299=', 'answer': 4324, 'gen': '4324E'}
# 143200
# {'question': 'B568-5320=', 'answer': -4752, 'gen': '-4752E'}
# 143400
# {'question': 'B4759*8200=', 'answer': 39023800, 'gen': '39549800E'}
# 143600
# ...
# 476000
# {'question': 'B6254*9265=', 'answer': 57943310, 'gen': '57946110E'}
# 476200
# {'question': 'B2002-864=', 'answer': 1138, 'gen': '1148E'}
# 476400
# {'question': 'B7201-7213=', 'answer': -12, 'gen': '-P12E'}
# 476600
# {'question': 'B3295/9303=', 'answer': 0, 'gen': '0E'}
# 476800
# {'question': 'B4273*6892=', 'answer': 29449516, 'gen': '30017196E'}
# 477000
# {'question': 'B1664*69=', 'answer': 114816, 'gen': '114376E'}
# 477200
# {'question': 'B2746/7438=', 'answer': 0, 'gen': '0E'}
# 477400
# {'question': 'B6558+3245=', 'answer': 9803, 'gen': 'P8033E'}
# 477600
# {'question': 'B256-955=', 'answer': -699, 'gen': '-751E'}
# 477800
# {'question': 'B7424/2778=', 'answer': 2, 'gen': '2E'}
# 478000
# {'question': 'B6932/7643=', 'answer': 0, 'gen': '0E'}
# 478200
# {'question': 'B1754/404=', 'answer': 4, 'gen': '4E'}
# 478400
# {'question': 'B442/967=', 'answer': 0, 'gen': '0E'}
# 478600
# {'question': 'B4771/6469=', 'answer': 0, 'gen': '0E'}
# 478800
# {'question': 'B659-7871=', 'answer': -7212, 'gen': '-7212E'}
# 479000
# {'question': 'B5277*1646=', 'answer': 8685942, 'gen': '8245222E'}
# 479200
# {'question': 'B6000*3785=', 'answer': 22710000, 'gen': '22660000E'}
# 479400
# {'question': 'B553*1791=', 'answer': 990423, 'gen': '961283E'}
# 479600
# {'question': 'B7890-3548=', 'answer': 4342, 'gen': '4342E'}
# 479800
# {'question': 'B6498/3148=', 'answer': 2, 'gen': '2E'}
# 480000
# {'question': 'B3836-8229=', 'answer': -4393, 'gen': '-4393E'}
# 480200
# {'question': 'B6640+1189=', 'answer': 7829, 'gen': '7829E'}
# 480400
# {'question': 'B9341+7219=', 'answer': 16560, 'gen': '16560E'}
# 480600
# {'question': 'B91*7616=', 'answer': 693056, 'gen': '684376E'}
# 480800
# {'question': 'B6695+6924=', 'answer': 13619, 'gen': '13619E'}
# 481000
# {'question': 'B5504/3821=', 'answer': 1, 'gen': '1E'}
# 481200
# {'question': 'B9697*7895=', 'answer': 76557815, 'gen': '76412915E'}
# 481400
# {'question': 'B4274*3474=', 'answer': 14847876, 'gen': '14788816E'}
# 481600
# {'question': 'B4239+7959=', 'answer': 12198, 'gen': '12198E'}
# 481800
# {'question': 'B1789/6173=', 'answer': 0, 'gen': '0E'}
# 482000
# {'question': 'B2048-8392=', 'answer': -6344, 'gen': '-6344E'}
# 482200
# {'question': 'B9969-4897=', 'answer': 5072, 'gen': '5072E'}
# 482400
# {'question': 'B1444-3617=', 'answer': -2173, 'gen': '-2173E'}
# 482600
# {'question': 'B8036*145=', 'answer': 1165220, 'gen': '1182820E'}
# 482800
# {'question': 'B2029/9516=', 'answer': 0, 'gen': '0E'}
# 483000
# {'question': 'B5642*8722=', 'answer': 49209524, 'gen': '47931884E'}
# 483200
# {'question': 'B1989-4403=', 'answer': -2414, 'gen': '-2414E'}
# 483400
# {'question': 'B2056*2242=', 'answer': 4609552, 'gen': '4438552E'}
# 483600
# {'question': 'B5054-9332=', 'answer': -4278, 'gen': '-4278E'}
# 483800
# {'question': 'B7299/3886=', 'answer': 1, 'gen': '1E'}
# 484000
# {'question': 'B7781+7127=', 'answer': 14908, 'gen': '14908E'}
# 484200
# {'question': 'B5281+5709=', 'answer': 10990, 'gen': '10990E'}
# 484400
# {'question': 'B9145+2824=', 'answer': 11969, 'gen': '11969E'}
# 484600
# {'question': 'B170/9410=', 'answer': 0, 'gen': '0E'}
# 484800
# {'question': 'B7154-331=', 'answer': 6823, 'gen': '6823E'}
# 485000
# {'question': 'B1376/9296=', 'answer': 0, 'gen': '0E'}
# 485200
# {'question': 'B7647*6533=', 'answer': 49957851, 'gen': '48392931E'}
# 485400
# {'question': 'B6957+1699=', 'answer': 8656, 'gen': '8656E'}
# 485600
# {'question': 'B7263*2436=', 'answer': 17692668, 'gen': '17989808E'}
# 485800
# {'question': 'B5499-683=', 'answer': 4816, 'gen': '4716E'}
# 486000
# {'question': 'B5897-4961=', 'answer': 936, 'gen': '936E'}
# 486200
# {'question': 'B8943/7333=', 'answer': 1, 'gen': '1E'}
# 486400
# {'question': 'B7811*8438=', 'answer': 65909218, 'gen': '66266278E'}
# 486600
# {'question': 'B1383*9224=', 'answer': 12756792, 'gen': '13075396E'}
# 486800
# {'question': 'B4596*5683=', 'answer': 26119068, 'gen': '26628708E'}
# 487000
# {'question': 'B5004+9326=', 'answer': 14330, 'gen': '14330E'}
# 487200
# {'question': 'B5861+8300=', 'answer': 14161, 'gen': '14161E'}
# 487400
# {'question': 'B8564-9284=', 'answer': -720, 'gen': '-720E'}
# 487600
# {'question': 'B3018-4580=', 'answer': -1562, 'gen': '-1562E'}
# 487800
# {'question': 'B1803-2518=', 'answer': -715, 'gen': '-715E'}
# 488000
# {'question': 'B5081-6099=', 'answer': -1018, 'gen': 'PE'}
# 488200
# {'question': 'B3196/3103=', 'answer': 1, 'gen': 'PE'}
# 488400
# {'question': 'B8219-3046=', 'answer': 5173, 'gen': '5173E'}
# 488600
# {'question': 'B34/28=', 'answer': 1, 'gen': 'PE'}
# 488800
# {'question': 'B286/8413=', 'answer': 0, 'gen': '0E'}
# 489000
# {'question': 'B3876-6495=', 'answer': -2619, 'gen': '-2619E'}
# 489200
# {'question': 'B382+7970=', 'answer': 8352, 'gen': '8352E'}
# 489400
# {'question': 'B1114+4496=', 'answer': 5610, 'gen': '5610E'}
# 489600
# {'question': 'B9617*9947=', 'answer': 95660299, 'gen': '95400059E'}
# 489800
# {'question': 'B88+8058=', 'answer': 8146, 'gen': '8146E'}
# 490000
# {'question': 'B8149/6192=', 'answer': 1, 'gen': '1E'}
# 490200
# {'question': 'B6767-9392=', 'answer': -2625, 'gen': '-2625E'}
# 490400
# {'question': 'B9344+1750=', 'answer': 11094, 'gen': '11094E'}
# 490600
# {'question': 'B8589/5353=', 'answer': 1, 'gen': '1E'}
# 490800
# {'question': 'B6380-2930=', 'answer': 3450, 'gen': '3450E'}
# 491000
# {'question': 'B482/9970=', 'answer': 0, 'gen': '0E'}
# 491200
# {'question': 'B7164/3367=', 'answer': 2, 'gen': '2E'}
# 491400
# {'question': 'B9694+1405=', 'answer': 11099, 'gen': '11099E'}
# 491600
# {'question': 'B252/649=', 'answer': 0, 'gen': '0E'}
# 491800
# {'question': 'B5140/6580=', 'answer': 0, 'gen': '0E'}
# 492000
# {'question': 'B240/6130=', 'answer': 0, 'gen': '0E'}
# 492200
# {'question': 'B3933*1490=', 'answer': 5860170, 'gen': '6199570E'}
# 492400
# {'question': 'B1341+9614=', 'answer': 10955, 'gen': '10955E'}
# 492600
# {'question': 'B3779+1442=', 'answer': 5221, 'gen': '5221E'}
# 492800
# {'question': 'B3690*1439=', 'answer': 5309910, 'gen': '5581510E'}
# 493000
# {'question': 'B2455-5760=', 'answer': -3305, 'gen': '-3305E'}
# 493200
# {'question': 'B5522+8442=', 'answer': 13964, 'gen': '13964E'}
# 493400
# {'question': 'B3518*396=', 'answer': 1393128, 'gen': '1413428E'}
# 493600
# {'question': 'B9755+9809=', 'answer': 19564, 'gen': '19564E'}
# 493800
# {'question': 'B527-1545=', 'answer': -1018, 'gen': '-1018E'}
# 494000
# {'question': 'B11+2415=', 'answer': 2426, 'gen': '2426E'}
# 494200
# {'question': 'B4974/7350=', 'answer': 0, 'gen': '0E'}
# 494400
# {'question': 'B1357-8859=', 'answer': -7502, 'gen': '-7502E'}
# 494600
# {'question': 'B1386/9788=', 'answer': 0, 'gen': '0E'}
# 494800
# {'question': 'B6307*8045=', 'answer': 50739815, 'gen': '49791015E'}
# 495000
# {'question': 'B1174-9189=', 'answer': -8015, 'gen': '-7015E'}
# 495200
# {'question': 'B7434/1282=', 'answer': 5, 'gen': '5E'}
# 495400
# {'question': 'B42-4204=', 'answer': -4162, 'gen': '-4162E'}
# 495600
# {'question': 'B1763+2917=', 'answer': 4680, 'gen': '4680E'}
# 495800
# {'question': 'B2779*9531=', 'answer': 26486649, 'gen': '26766189E'}
# 496000
# {'question': 'B7705/8698=', 'answer': 0, 'gen': '0E'}
# 496200
# {'question': 'B6768/320=', 'answer': 21, 'gen': '22E'}
# 496400
# {'question': 'B4120/223=', 'answer': 18, 'gen': '17E'}
# 496600
# {'question': 'B7387-9782=', 'answer': -2395, 'gen': '-2395E'}
# 496800
# {'question': 'B8753*9369=', 'answer': 82006857, 'gen': '82022697E'}
# 497000
# {'question': 'B928-1628=', 'answer': -700, 'gen': '-P700E'}
# 497200
# {'question': 'B5948+3519=', 'answer': 9467, 'gen': '9467E'}
# 497400
# {'question': 'B9202+1392=', 'answer': 10594, 'gen': '10594E'}
# 497600
# {'question': 'B7212/2585=', 'answer': 2, 'gen': '2E'}
# 497800
# {'question': 'B8938+4954=', 'answer': 13892, 'gen': '13892E'}
# 498000
# {'question': 'B6496-317=', 'answer': 6179, 'gen': '6189E'}
# 498200
# {'question': 'B8589*4313=', 'answer': 37044357, 'gen': '36494597E'}
# 498400
# {'question': 'B2688/9543=', 'answer': 0, 'gen': '0E'}
# 498600
# {'question': 'B4412*2153=', 'answer': 9499036, 'gen': '8978776E'}
# 498800
# {'question': 'B5448/6430=', 'answer': 0, 'gen': '0E'}
# 499000
# {'question': 'B9316/2950=', 'answer': 3, 'gen': '3E'}
# 499200
# {'question': 'B9840+3475=', 'answer': 13315, 'gen': '13315E'}
# 499400
# {'question': 'B9609+3378=', 'answer': 12987, 'gen': '12987E'}
# 499600
# {'question': 'B6632-2823=', 'answer': 3809, 'gen': '3809E'}
# 499800
# {'question': 'B9684+4471=', 'answer': 14155, 'gen': '14155E'}
# 500000
# {'question': 'B2754/8115=', 'answer': 0, 'gen': '0E'}
# 500200
# {'question': 'B1506/4873=', 'answer': 0, 'gen': '0E'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 for i in range(1_0000_0000):
# ----> 2     train(*get_data(next(iter(loader))))
#       4     if i % 200 == 0:
#       5         print(i)
#
# File ~/miniconda3/envs/pt2/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[7], line 7, in get_data(question)
#       4 @torch.no_grad()
#       5 def get_data(question):
#       6     #====answer====
# ----> 7     answer = model_actor.generate(
#       8         input_ids=question,
#       9         attention_mask=(question != tokenizer.pad_token_id).long(),
#      10         min_length=-1,
#      11         max_length=50,
#      12         pad_token_id=tokenizer.pad_token_id,
#      13         eos_token_id=tokenizer.eos_token_id,
#      14         top_k=0.0,
#      15         top_p=1.0,
#      16         do_sample=True)
#      18     answer = answer[:, question.shape[1]:]
#      20     #求结束位置
#
# File ~/miniconda3/envs/pt2/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/pt2/lib/python3.10/site-packages/transformers/generation/utils.py:2255, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2247     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2248         input_ids=input_ids,
#    2249         expand_size=generation_config.num_return_sequences,
#    2250         is_encoder_decoder=self.config.is_encoder_decoder,
#    2251         **model_kwargs,
#    2252     )
#    2254     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255     result = self._sample(
#    2256         input_ids,
#    2257         logits_processor=prepared_logits_processor,
#    2258         stopping_criteria=prepared_stopping_criteria,
#    2259         generation_config=generation_config,
#    2260         synced_gpus=synced_gpus,
#    2261         streamer=streamer,
#    2262         **model_kwargs,
#    2263     )
#    2265 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2266     # 11. prepare beam search scorer
#    2267     beam_scorer = BeamSearchScorer(
#    2268         batch_size=batch_size,
#    2269         num_beams=generation_config.num_beams,
#    (...)
#    2274         max_length=generation_config.max_length,
#    2275     )
#
# File ~/miniconda3/envs/pt2/lib/python3.10/site-packages/transformers/generation/utils.py:3247, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3242 is_prefill = True
#    3243 while self._has_unfinished_sequences(
#    3244     this_peer_finished, synced_gpus, device=input_ids.device, cur_len=cur_len, max_length=max_length
#    3245 ):
#    3246     # prepare model inputs
# -> 3247     model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    3249     # prepare variable output controls (note: some models won't accept all output controls)
#    3250     model_inputs.update({"output_attentions": output_attentions} if output_attentions else {})
#
# File ~/miniconda3/envs/pt2/lib/python3.10/site-packages/transformers/generation/utils.py:412, in GenerationMixin.prepare_inputs_for_generation(self, input_ids, past_key_values, attention_mask, inputs_embeds, cache_position, **kwargs)
#     406     model_inputs[input_ids_key] = input_ids.clone(memory_format=torch.contiguous_format)
#     408 # 4. Create missing `position_ids` on the fly
#     409 if (
#     410     attention_mask is not None
#     411     and kwargs.get("position_ids") is None
# --> 412     and "position_ids" in set(inspect.signature(self.forward).parameters.keys())
#     413 ):
#     414     position_ids = attention_mask.long().cumsum(-1) - 1
#     415     position_ids.masked_fill_(attention_mask == 0, 1)
#
# File ~/miniconda3/envs/pt2/lib/python3.10/inspect.py:3254, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3252 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3253     """Get a signature object for the passed callable."""
# -> 3254     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3255                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/envs/pt2/lib/python3.10/inspect.py:3002, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    2998 @classmethod
#    2999 def from_callable(cls, obj, *,
#    3000                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3001     """Constructs Signature for the given callable object."""
# -> 3002     return _signature_from_callable(obj, sigcls=cls,
#    3003                                     follow_wrapper_chains=follow_wrapped,
#    3004                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File ~/miniconda3/envs/pt2/lib/python3.10/inspect.py:2401, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2396     raise TypeError('{!r} is not a callable object'.format(obj))
#    2398 if isinstance(obj, types.MethodType):
#    2399     # In this case we skip the first parameter of the underlying
#    2400     # function (usually `self` or `cls`).
# -> 2401     sig = _get_signature_of(obj.__func__)
#    2403     if skip_bound_arg:
#    2404         return _signature_bound_method(sig)
#
# File ~/miniconda3/envs/pt2/lib/python3.10/inspect.py:2463, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2458             return sig.replace(parameters=new_params)
#    2460 if isfunction(obj) or _signature_is_functionlike(obj):
#    2461     # If it's a pure Python function, or an object that is duck type
#    2462     # of a Python function (Cython functions, for instance), then:
# -> 2463     return _signature_from_function(sigcls, obj,
#    2464                                     skip_bound_arg=skip_bound_arg,
#    2465                                     globals=globals, locals=locals, eval_str=eval_str)
#    2467 if _signature_is_builtin(obj):
#    2468     return _signature_from_builtin(sigcls, obj,
#    2469                                    skip_bound_arg=skip_bound_arg)
#
# File ~/miniconda3/envs/pt2/lib/python3.10/inspect.py:2334, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2332 kind = _POSITIONAL_ONLY if posonly_left else _POSITIONAL_OR_KEYWORD
#    2333 annotation = annotations.get(name, _empty)
# -> 2334 parameters.append(Parameter(name, annotation=annotation,
#    2335                             kind=kind,
#    2336                             default=defaults[offset]))
#    2337 if posonly_left:
#    2338     posonly_left -= 1
#
# File ~/miniconda3/envs/pt2/lib/python3.10/inspect.py:2643, in Parameter.__init__(self, name, kind, default, annotation)
#    2641     raise ValueError(f'value {kind!r} is not a valid Parameter.kind')
#    2642 if default is not _empty:
# -> 2643     if self._kind in (_VAR_POSITIONAL, _VAR_KEYWORD):
#    2644         msg = '{} parameters cannot have default values'
#    2645         msg = msg.format(self._kind.description)
#
# KeyboardInterrupt:
